# %%
import pandas as pd
import numpy as np
#import polars as pl
import os
import re
#importo sqlalchemy y mi variable de entorno para conectarme a la base de datos
from sqlalchemy import create_engine
from dotenv import load_dotenv
#import unicodedata

# %%
# Cargar variables del .env
load_dotenv()

DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")

DATABASE_URL = (
    f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}"
    f"@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

engine = create_engine(
    DATABASE_URL,
    pool_pre_ping=True,
    pool_size=5,
    max_overflow=10
)

# %%
#pruebo que la conexión sea existosa
df = pd.read_sql("SELECT * FROM bronze.datosctes_saps", engine)
df.head()
# Out:
#    id_saps                   saps          barrio  \
# 0       76     Dr. Romilio Monzón         Cichero
# 1      128     Dr. Anibal Malvido         Pirayui
# 2       49   Dr. Benjamin Serrano  Parque Cadenas
# 3       31       Dr. Elias Galvan          Galvan
# 4       38  Dr. JC Benitez Suarez           Lomas
#
#                                       ubicacion contacto_telefono  \
# 0                  Guido Spano y Velez Sarfield        3794570325
# 1                      Suecia y Guillermo Ojeda        3794521654
# 2                               Ruta 5 km.2 1/2        3794293513
# 3                     Alverdi 2500 esq. Pizarro        3794815817
# 4  Mz. 1 Casa 1. Calles S. Mancini y Juan Pa.II        3794033767
#
#             responsable     cargo
# 0          Suarez Nancy  Director
# 1  Atoche Gennel Roland  Director
# 2          Rezett Diego  Director
# 3  Lezcano Walter Ruben  Director
# 4         Romero Monica  Director

# %%
#para obtener el path de los datos. Esto nos da algo como lo que sigue:
#c:\Users\espin\OneDrive\Documentos\Codo A Codo\Proyecto_Ctes_CAPS\notebooks\extract\datos
#que es la ruta donde se encuentra la carpeta datos. Pero yo tengo los datos en la base
#así que uso esta estrategia para obtener la ruta.
path_data=os.path.join(os.getcwd())
path_data=path_data[0:path_data.find('Proyecto_Ctes_CAPS')]+'Proyecto_CTES_Caps\datos'

path_file=lambda x:os.path.join(path_data,x)
print("Ruta del archivo csv: ")
print(path_file('prestaciones_enfermeria.csv'))
# Out:
# Ruta del archivo csv:
# c:\Users\espin\OneDrive\Documentos\Codo A Codo\Proyecto_CTES_Caps\datos\prestaciones_enfermeria.csv

# %% [markdown]
# Existen variaciones dependiendo de las fuentes de datos.
# ![image.png](attachment:image.png)
#
# En la imagen se ve alguno de los argumentos que podemos pasarle a read_csv:
#
# filepath_or_buffer: Es la ruta con el nombre y extensión del archivo que se quiere cargar.
#
# skiprows=valor: No carga las primeras filas del archivo, indicado por valor. Así, skiprows=3, no cargará las primeras tres filas del archivo.
#
# delimiter: Indica el delimitador de filas. Por ejemplo, delimiter=';' indica que cada fila de datos está separado de las otras por el punto y coma.
#
# header: Indica si el archivo posee o no cabecera.
#
# skipfooter=valor: Indica cuántas filas del fila se omiten.
#
# names=arregloStrings: Le asigna esos nombres a las cabeceras de los datos. Debe ser un arreglo de strings con un total de strings igual a las columnas del archivo leído.
#
# También es posible cargar los datos desde un archivo Excel.
#
# ![image-2.png](attachment:image-2.png)
#
# Allí se ve el método para cargar el archivo junto con otros métodos como el que sirve para obtener las hojas del archivo.
# Un truco interesante es que si cada hoja tiene la misma estructura: tienen las mismas columnas, del mismo tipo de datos y tienen el mismo significado; podemos combinarlas en un solo dataframe.
#
# ![image-3.png](attachment:image-3.png)
#
# df_full_excel es el dataframe final. Con pd.concat combinamos los diferentes dataframes. Debe tenerse en cuenta que se concatenarán las filas, así que cada columna debe tener el mismo nombre y cada archivo debe tener la misma cantidad de columnas. Con pd.read_excel(xls, sheet_name=sheet) for sheet in xls.sheet_name lo que estamos haciendo es crear un dataframe por cada hoja del archivo Excel. xls es el nombre que le dimos arriba a nuestro dataframe que contiene todo el archivo excel, y luego extraemos hoja por hoja para crear un dataframe por cada una de ellas. Luego, indicamos que se ignoren los índices.
# También podemos usar Polar para leer los archivos:
#
# ![image-4.png](attachment:image-4.png)
#
# Polar es mejor para carga de datos masivos y más eficiencia. Además, vemos que la sintaxis es un poco diferente. Una cuestión interesante es que Polar utiliza distintos motores para cargar los datos, así que conviene revisar la documentación para saber cuál conviene usar.
#
# Otra forma de abrir los archivos Excel, es usando el siguiente código de ejemplo:
#
# ![image-5.png](attachment:image-5.png)
#
# En Polar es más sencillo concatenar las hojas de un archivo Excel
#
# ![image-7.png](attachment:image-7.png)
#
# Recordar que en este ejemplo, las hojas del archivo Excel deben tener las mismas columnas con los mismos nombres. Básicamente, cada hoja debe contener una tabla de valores iguales. Por ejemplo, en una hoja tenemos las ventas del año 2020 y en otra la del 2021. En ambas hojas tenemos las mismas columnas con los mismos nombres, que representan los mismos datos de ventas pero para años distintos.
#
# Veamos un ejemplo de los esquemas para Polar cuando se lee un archivo. Supongamos que leímos un archivo de Excel que tiene la siguiente estructura:
#
# ![image-6.png](attachment:image-6.png)
#
# Para nuestro trabajo, resulta que todos los campos exceptuando el primero deben ser de tipo flotante. Pero notamos que son de tipo string (eso lo vemos por el str que se muestra en cada columna).
# Podemos cambiar esto de la siguiente manera:
#
# ![image-8.png](attachment:image-8.png)
#
# En este ejemplo, la parte
# schema_override={**{'in million USD':pl.String,"FY '09":pl.Float64}}
#
# Nos está diciendo: la columna cuyo nombre sea 'in million USD' conviérte su tipo de dato a string, y la columna cuyo nombre es 'FY '09' conviérte su tipo a flotante.

# %% [markdown]
# # Carga de datos a la capa bronce

# %% [markdown]
# Aquí realizaré una carga directa a la capa de bronce. Para saber qué tabla debo crear, primero revisaré la estructura de las tablas, sólo teniendo en cuenta sus campos y los tipos de datos que debe tener cada tabla. Luego, crearé la sentencia SQL para crear esas tablas en SQL. Para crear la tabla usaré código SQL puro, pero para cargar los datos usaré SQLAlchemy.

# %%
#leo el archivo
df_pato=pd.read_csv(path_file('consultas_por_patologia.csv'))
#Como hay columnas que no nos interesa, establezco las columnas pertinentes para el análisis
#columnas_requeridas=['ID_SAPS','SAPS','fecha','patologia_desc','agrupacion_CIE10','patologia_cod','id_rango_etario\n','consulta_cantidad','rango_etario','sexo']
#sólo tomo las columnas que van a ser utilizadas
#df_pato=df_pato[columnas_requeridas]
#modifico los nombres para eliminar errores de tipeo
#df_pato.columns=['ID_SAPS','SAPS','fecha','patologia_desc','agrupacion_CIE10','patologia_cod','id_rango_etario','consulta_cantidad','rango_etario','sexo']
df_pato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167201 entries, 0 to 167200
# Data columns (total 32 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID_SAPS               66424 non-null   object
#  1   SAPS                  166147 non-null  object
#  2   fecha                 167200 non-null  object
#  3   mes                   167201 non-null  int64
#  4   año                   167201 non-null  int64
#  5   patologia_desc        166916 non-null  object
#  6   agrupacion_CIE10      166913 non-null  object
#  7   patologia_cod         167175 non-null  object
#  8   id_rango_etario       166135 non-null  object
#  9   id_sexo               166136 non-null  float64
#  10  consulta_cantidad     166132 non-null  object
#  11  rango_etario          166129 non-null  object
#  12  sexo                  166053 non-null  object
#  13  Barrio del Operativo  4953 non-null    object
#  14  Unnamed: 14           0 non-null       float64
#  15  Unnamed: 15           0 non-null       float64
#  16  Unnamed: 16           0 non-null       float64
#  17  Unnamed: 17           0 non-null       float64
#  18  Unnamed: 18           0 non-null       float64
#  19  Unnamed: 19           0 non-null       float64
#  20  Unnamed: 20           0 non-null       float64
#  21  Unnamed: 21           0 non-null       float64
#  22  Unnamed: 22           0 non-null       float64
#  23  Unnamed: 23           0 non-null       float64
#  24  Unnamed: 24           0 non-null       float64
#  25  Unnamed: 25           0 non-null       float64
#  26  Unnamed: 26           0 non-null       float64
#  27  Unnamed: 27           0 non-null       float64
#  28  Unnamed: 28           0 non-null       float64
#  29  Unnamed: 29           0 non-null       float64
#  30  Unnamed: 30           0 non-null       float64
#  31  Unnamed: 31           1 non-null       object
# dtypes: float64(18), int64(2), object(12)
# memory usage: 40.8+ MB
# C:\Users\espin\AppData\Local\Temp\ipykernel_11128\917599064.py:2: DtypeWarning: Columns (0,8,10,13,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pato=pd.read_csv(path_file('consultas_por_patologia.csv'))

# %% [markdown]
# Al analizar los campos de la tabla, notamos que tiene 31 campos. Muchos de esos campos no tienen un nombre descriptivo y están vacíos. Como no tenemos la capacidad para hablar con los responsable de los datos, optaremos por conservar todas la columnas como una cuestión de auditoría. Esto servirá para decir "En nuestros datos originales, había ésto.".
# Las columnas que sean de tipo Object, las trataremos como Text en nuestra base de datos. No haremos ningún tipo de transformación aquí. Pero antes, debemos darles nombres significativos a las columnas

# %%
df_pato.columns=(
    df_pato.columns.str.replace(":","")
    .str.replace(" ","_")
)
df_pato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167201 entries, 0 to 167200
# Data columns (total 32 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID_SAPS               66424 non-null   object
#  1   SAPS                  166147 non-null  object
#  2   fecha                 167200 non-null  object
#  3   mes                   167201 non-null  int64
#  4   año                   167201 non-null  int64
#  5   patologia_desc        166916 non-null  object
#  6   agrupacion_CIE10      166913 non-null  object
#  7   patologia_cod         167175 non-null  object
#  8   id_rango_etario       166135 non-null  object
#  9   id_sexo               166136 non-null  float64
#  10  consulta_cantidad     166132 non-null  object
#  11  rango_etario          166129 non-null  object
#  12  sexo                  166053 non-null  object
#  13  Barrio_del_Operativo  4953 non-null    object
#  14  Unnamed_14            0 non-null       float64
#  15  Unnamed_15            0 non-null       float64
#  16  Unnamed_16            0 non-null       float64
#  17  Unnamed_17            0 non-null       float64
#  18  Unnamed_18            0 non-null       float64
#  19  Unnamed_19            0 non-null       float64
#  20  Unnamed_20            0 non-null       float64
#  21  Unnamed_21            0 non-null       float64
#  22  Unnamed_22            0 non-null       float64
#  23  Unnamed_23            0 non-null       float64
#  24  Unnamed_24            0 non-null       float64
#  25  Unnamed_25            0 non-null       float64
#  26  Unnamed_26            0 non-null       float64
#  27  Unnamed_27            0 non-null       float64
#  28  Unnamed_28            0 non-null       float64
#  29  Unnamed_29            0 non-null       float64
#  30  Unnamed_30            0 non-null       float64
#  31  Unnamed_31            1 non-null       object
# dtypes: float64(18), int64(2), object(12)
# memory usage: 40.8+ MB

# %%
list_unnamed=[]
for i in range(14,df_pato.shape[1]):
    list_unnamed.append(f"Unnamed_{i}")
 
df_pato[list_unnamed].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167201 entries, 0 to 167200
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed_14  0 non-null      float64
#  1   Unnamed_15  0 non-null      float64
#  2   Unnamed_16  0 non-null      float64
#  3   Unnamed_17  0 non-null      float64
#  4   Unnamed_18  0 non-null      float64
#  5   Unnamed_19  0 non-null      float64
#  6   Unnamed_20  0 non-null      float64
#  7   Unnamed_21  0 non-null      float64
#  8   Unnamed_22  0 non-null      float64
#  9   Unnamed_23  0 non-null      float64
#  10  Unnamed_24  0 non-null      float64
#  11  Unnamed_25  0 non-null      float64
#  12  Unnamed_26  0 non-null      float64
#  13  Unnamed_27  0 non-null      float64
#  14  Unnamed_28  0 non-null      float64
#  15  Unnamed_29  0 non-null      float64
#  16  Unnamed_30  0 non-null      float64
#  17  Unnamed_31  1 non-null      object
# dtypes: float64(17), object(1)
# memory usage: 23.0+ MB

# %% [markdown]
# En mi opinión, estas columnas son columnas basura. Pero como la teoría dice que debemos guardar los datos exactamente como vienen de la fuente, deberían quedarse esas columnas. Revisemos para las demás tablas.

# %%
df_saps=pd.read_csv(path_file('listado_saps.csv'))
df_saps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   saps               38 non-null     object
#  1   barrio             37 non-null     object
#  2   ubicacion          38 non-null     object
#  3   contacto_telefono  38 non-null     int64
#  4   responsable        38 non-null     object
#  5   cargo              37 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.9+ KB

# %%
df_inmu=pd.read_csv(path_file('inmunizaciones.csv'))
df_inmu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27004 entries, 0 to 27003
# Data columns (total 26 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   ID_SAPS                                                              18862 non-null  object
#  1   SAPS                                                                 26003 non-null  object
#  2   fecha                                                                26003 non-null  object
#  3   mes                                                                  26999 non-null  object
#  4   año                                                                  26999 non-null  object
#  5   vacunas_tipo                                                         25984 non-null  object
#  6   vacunas_cantidad                                                     25983 non-null  object
#  7   Barrio del Operativo                                                 404 non-null    object
#  8   En caso de ser Operativo Territorial Indicar el Barrio en columna H  0 non-null      float64
#  9   Unnamed: 9                                                           1 non-null      object
#  10  Unnamed: 10                                                          0 non-null      float64
#  11  Unnamed: 11                                                          0 non-null      float64
#  12  Unnamed: 12                                                          0 non-null      float64
#  13  Unnamed: 13                                                          0 non-null      float64
#  14  Unnamed: 14                                                          0 non-null      float64
#  15  Unnamed: 15                                                          0 non-null      float64
#  16  Unnamed: 16                                                          0 non-null      float64
#  17  Unnamed: 17                                                          0 non-null      float64
#  18  Unnamed: 18                                                          0 non-null      float64
#  19  Unnamed: 19                                                          0 non-null      float64
#  20  Unnamed: 20                                                          0 non-null      float64
#  21  Unnamed: 21                                                          0 non-null      float64
#  22  Unnamed: 22                                                          0 non-null      float64
#  23  Unnamed: 23                                                          0 non-null      float64
#  24  Unnamed: 24                                                          0 non-null      float64
#  25  Unnamed: 25                                                          1 non-null      object
# dtypes: float64(16), object(10)
# memory usage: 5.4+ MB

# %% [markdown]
# Para el caso de las imunizaciones, tenemos una situación similar a la tabla de consultas. Así que vamos a repetir el proceso de limpieza para esa tabla

# %%
df_inmu.columns=(
    df_inmu.columns.str.replace(":","")
    .str.replace(" ","_")
)
df_inmu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27004 entries, 0 to 27003
# Data columns (total 26 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   ID_SAPS                                                              18862 non-null  object
#  1   SAPS                                                                 26003 non-null  object
#  2   fecha                                                                26003 non-null  object
#  3   mes                                                                  26999 non-null  object
#  4   año                                                                  26999 non-null  object
#  5   vacunas_tipo                                                         25984 non-null  object
#  6   vacunas_cantidad                                                     25983 non-null  object
#  7   Barrio_del_Operativo                                                 404 non-null    object
#  8   En_caso_de_ser_Operativo_Territorial_Indicar_el_Barrio_en_columna_H  0 non-null      float64
#  9   Unnamed_9                                                            1 non-null      object
#  10  Unnamed_10                                                           0 non-null      float64
#  11  Unnamed_11                                                           0 non-null      float64
#  12  Unnamed_12                                                           0 non-null      float64
#  13  Unnamed_13                                                           0 non-null      float64
#  14  Unnamed_14                                                           0 non-null      float64
#  15  Unnamed_15                                                           0 non-null      float64
#  16  Unnamed_16                                                           0 non-null      float64
#  17  Unnamed_17                                                           0 non-null      float64
#  18  Unnamed_18                                                           0 non-null      float64
#  19  Unnamed_19                                                           0 non-null      float64
#  20  Unnamed_20                                                           0 non-null      float64
#  21  Unnamed_21                                                           0 non-null      float64
#  22  Unnamed_22                                                           0 non-null      float64
#  23  Unnamed_23                                                           0 non-null      float64
#  24  Unnamed_24                                                           0 non-null      float64
#  25  Unnamed_25                                                           1 non-null      object
# dtypes: float64(16), object(10)
# memory usage: 5.4+ MB

# %% [markdown]
# Nos damos cuenta que la columna titulada "En_caso_de_ser_Operativo_Territorial_Indicar_el_Barrio_en_columna_H" es muy larga. Voy a modificarla para que sea más entendible

# %%
df_inmu.columns=df_inmu.columns.str.replace("En_caso_de_ser_Operativo_Territorial_Indicar_el_Barrio_en_columna_H","aviso_operativo_territorial")
df_inmu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27004 entries, 0 to 27003
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID_SAPS                      18862 non-null  object
#  1   SAPS                         26003 non-null  object
#  2   fecha                        26003 non-null  object
#  3   mes                          26999 non-null  object
#  4   año                          26999 non-null  object
#  5   vacunas_tipo                 25984 non-null  object
#  6   vacunas_cantidad             25983 non-null  object
#  7   Barrio_del_Operativo         404 non-null    object
#  8   aviso_operativo_territorial  0 non-null      float64
#  9   Unnamed_9                    1 non-null      object
#  10  Unnamed_10                   0 non-null      float64
#  11  Unnamed_11                   0 non-null      float64
#  12  Unnamed_12                   0 non-null      float64
#  13  Unnamed_13                   0 non-null      float64
#  14  Unnamed_14                   0 non-null      float64
#  15  Unnamed_15                   0 non-null      float64
#  16  Unnamed_16                   0 non-null      float64
#  17  Unnamed_17                   0 non-null      float64
#  18  Unnamed_18                   0 non-null      float64
#  19  Unnamed_19                   0 non-null      float64
#  20  Unnamed_20                   0 non-null      float64
#  21  Unnamed_21                   0 non-null      float64
#  22  Unnamed_22                   0 non-null      float64
#  23  Unnamed_23                   0 non-null      float64
#  24  Unnamed_24                   0 non-null      float64
#  25  Unnamed_25                   1 non-null      object
# dtypes: float64(16), object(10)
# memory usage: 5.4+ MB

# %%
df_cie10=pd.read_csv(path_file('tabla-salud-id_cie10.csv'))
df_cie10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1114 entries, 0 to 1113
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID_patologia       1114 non-null   object
#  1   TIPO DE PATOLOGIA  1114 non-null   object
#  2   Descripción        1114 non-null   object
# dtypes: object(3)
# memory usage: 26.2+ KB

# %% [markdown]
# Creamos el código para la creación de las tablas en SQL y ahora vamos a cargar los datos en las tablas

# %%
table_name = "datosctes_consultas_patologia"
schema = "bronze"   # ajustá si corresponde

with engine.begin() as conn:
    # 1. TRUNCATE (mucho más rápido que DELETE)
    conn.execute(
        f"TRUNCATE TABLE {schema}.{table_name}"
    )

    # 2. CARGA COMPLETA
    df_inmu.to_sql(
        name=table_name,
        con=conn,
        schema=schema,
        if_exists="append",
        index=False,
        method="multi",
        chunksize=2000
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\espin\OneDrive\Documentos\Codo A Codo\Proyecto_Ctes_CAPS\venv\Lib\site-packages\sqlalchemy\engine\base.py:1415, in Connection.execute(self, statement, parameters, execution_options)
#    1414 try:
# -> 1415     meth = statement._execute_on_connection
#    1416 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[16], line 6
#       2 schema = "bronze"   # ajustá si corresponde
#       4 with engine.begin() as conn:
#       5     # 1. TRUNCATE (mucho más rápido que DELETE)
# ----> 6     conn.execute(
#       7         f"TRUNCATE TABLE {schema}.{table_name}"
#       8     )
#      10     # 2. CARGA COMPLETA
#      11     df_inmu.to_sql(
#      12         name=table_name,
#      13         con=conn,
#    (...)     18         chunksize=2000
#      19     )
#
# File c:\Users\espin\OneDrive\Documentos\Codo A Codo\Proyecto_Ctes_CAPS\venv\Lib\site-packages\sqlalchemy\engine\base.py:1417, in Connection.execute(self, statement, parameters, execution_options)
#    1415     meth = statement._execute_on_connection
#    1416 except AttributeError as err:
# -> 1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
#    1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# ObjectNotExecutableError: Not an executable object: 'TRUNCATE TABLE bronze.datosctes_consultas_patologia'

# %% [markdown]
# Empecemos adaptando los tipos de datos. Por ejemplo, consulta_cantidad debería ser entero, mientras que fecha debería ser de tipo date. Realizando un primer análisis de la consulta_cantidad, notamos los siguientes resultados

# %%
df_pato['consulta_cantidad'].unique()
# Out:
# array(['18', '20', '22', '25', '1', '2', '4', '5', '15', '10', '3', '7',
#        '9', '6', '8', '13', '12', '14', '11', '16', '37', '21', '31',
#        '48', '29', '28', '32', '24', '26', '19', '27', '30', '17', '51',
#        '49', '57', '39', '55', '42', '33', '40', '45', '38', '58', '23',
#        '43', '47', '41', '35', '66', '50', '44', '46', '99', '83', '34',
#        '71', '60', '|1', '53', '61', '36', '59', '63', '62', 2.0, 3.0,
#        1.0, 4.0, 12.0, 6.0, 5.0, 7.0, 13.0, 9.0, 17.0, 15.0, 26.0, 38.0,
#        11.0, 23.0, 14.0, 10.0, 28.0, 8.0, 16.0, 20.0, 31.0, 18.0, 19.0,
#        29.0, 37.0, 35.0, 30.0, 22.0, 21.0, 46.0, 42.0, 52.0, 49.0, 32.0,
#        36.0, 39.0, 47.0, 45.0, 55.0, 25.0, 53.0, 27.0, 24.0, 34.0, 40.0,
#        50.0, 33.0, 86.0, 80.0, 43.0, 70.0, 56.0, 68.0, 41.0, 78.0, 62.0,
#        0.0, 117.0, 76.0, '70', '56', '68', '0', '1.', '.30', '52', '76',
#        '79', '98', '54', '74', '64', '.7', '69', '8+', '73', 0.5, 82.0,
#        57.0, 44.0, 64.0, 0.1, 95.0, 66.0, 0.2, 74.0, 136.0, 170.0, 59.0,
#        nan, 123.0, 142.0, 119.0, 48.0, 85.0, 88.0, 83.0, 63.0, '114',
#        '80', '78', '92', '88', '65', '104', '84', '135', '106', '4+',
#        '198', '85', '75', '82', '154', '8+4', 54.0, 89.0, 69.0, 58.0,
#        96.0, 77.0, '95', '141', '111', '67', '321', '72', '112', '0,6',
#        '138', '122', '133', '81', '163', '8/', '5+', '314', '188', '77'],
#       dtype=object)

# %% [markdown]
# Vemos algunos errores como ser
# - "4+" o "|1".
#
# Para esos casos vamos a eliminar los símbolos que no corresponden. Por ejemplo, podemos establecer que "4+" es en realidad 4 y para "|1" es el realidad 1.
#
# Luego existen casos como:
# - ".30"
# - "0.2"
#
# En este caso, suponemos que el punto y los valores a la izquierda del punto son errores de tipeo. Esto lo establecemos así porque la cantidad de consultas debe ser un número entero mayor o igual a cero. Sería poco probable que los profesionales de la salud colocaran valores decimales.
#
# Para el caso de "8+4", suponemos que se intentó realizar la suma y no se terminó de expresar la operación, quedando en formato de string.
# Los valores nan los transformamos a "-1" para indicar la ausencia de valores para ese día.

# %%
#limpio los datos para consulta_cantidad
#Acciones:
#Reemplazar comas por puntos para indicar los decimales
#Eliminar los puntos y números antes del punto
#Eliminar signos como +, |, /, etc
#Reemplazar los valores nan por -1
df_pato["consulta_cantidad"] = (
    df_pato["consulta_cantidad"]
        .astype(str)
        .str.replace(",", ".", regex=False)
        .str.replace("8+4", "12", regex=False)
        .str.replace(".7", "7", regex=False)
        .str.replace("0.5", "5", regex=False) 
        .str.replace(".30", "30", regex=False) 
        .str.replace("0.1", "1", regex=False) 
        .str.replace("0.2", "2", regex=False) 
        .str.replace("0.6", "6", regex=False)  
        .str.replace("+", "", regex=False)         
        .str.replace("|", "", regex=False)
        .str.replace("/", "", regex=False)
        .str.replace("nan", "-1",regex=False)
        .str.strip()
        .str.replace(".0","",regex=False)
        .str.replace(".","",regex=False)
        .astype(int)  
)

df_pato.isnull().sum()
# Out:
# ID_SAPS              100777
# SAPS                   1054
# fecha                     1
# patologia_desc          285
# agrupacion_CIE10        288
# patologia_cod            26
# id_rango_etario        1066
# consulta_cantidad         0
# rango_etario           1072
# sexo                   1148
# dtype: int64

# %% [markdown]
# # Analizando El Campo Fecha

# %% [markdown]
# Nuevamente, revisemos los valores únicos para las fechas

# %%
df_pato['fecha'].unique()
# Out:
# array(['2020-01-01', '01-01-2020', '01-02-2020', '01-03-2020',
#        '01-04-2020', '01-05-2020', '01/05', '01-06-2020', '01-07-2020',
#        '01-08-2020', '02-08-2020', '05-08-2020', '01-09-2020',
#        '01-10-2020', '01-11-2020', '01-12-2020', '01-01-2021',
#        '01/01/2021', '01-02-2021', '01-03-2021', '03-2021', '01-04-2021',
#        '01-05-2021', '01-06-2021', '02-06-2021', '04-06-2021',
#        '09-06-2021', '11-06-2021', '16-06-2021', '25-06-2021',
#        '30-06-2021', '01-07-2021', '08-07-2021', '14-07-2021',
#        '15-07-2021', '23-07-2021', '28-07-2021', '30-07-2021',
#        '07-07-2021', '21-07-2021', '02-07-2021', '01-08-2021',
#        '04-08-2021', '06-08-2021', '01-09-2021', '12-08-2021',
#        '05-08-2021', '20-08-2021', '18-08-2021', '11-08-2021',
#        '01-10-2021', '01-11-2021', '01/11/2021', '13-08-2021',
#        '03-09-2021', '03-11-2021', '23-11-2021', '17-09-2021',
#        '27-10-2021', '29-10-2021', '06-10-2021', '12-11-2021',
#        '24-11-2021', '17-11-2021', '20-10-2021', '13-10-2021',
#        '07-10-2021', '22-10-2021', '19-11-2021', '01-12-2021',
#        '01-01-2022', '01-01-2023', '01-02-2023', '01/02/2023',
#        '01-03-2023', '01-04-2023', '01/04/2023', '01-05-2023',
#        '01-06-2023', '01-07-2023', '01-08-2023', '01-09-2023',
#        '01-10-2023', '01-11-2023', '01-12-2023', '01-01-2024',
#        '01-02-2024', '01-03-2024', '01-04-2024', '01-05-2024',
#        '31-05-2024', '29-05-2024', '07-03-2024', '15-05-2024',
#        '17-05-2024', '27-05-2024', '01-06-2024', '19-06-2024',
#        '14-06-2024', '12-06-2024', '05-06-2024', '07-06-2024',
#        '26-06-2024', '28-06-2024', '01-07-2024', '03-07-2024',
#        '05-07-2024', '01-08-2024', '02-08-2024', '09-08-2024',
#        '14-08-2024', '16-08-2024', '28-08-2024', '30-08-2024',
#        '01-09-2024', '01-10-2024', '01-11-2024', '01-12-2024',
#        '01-01-2025', '01-12-2025', '01-02-2025', '01-03-2025',
#        '01-04-2025', '01-05-2025', '29-04-2025', '10-04-2025',
#        '15-04-2025', '08-04-2025', '22-04-2025', '24/04/2025',
#        '01-06-2025', '15-05-2025', '13-05-2025', '20-05-2025',
#        '29-05-2025', '22-05-2025', '01/06/2025', '01-07-2025',
#        '01-08-2025', nan], dtype=object)

# %% [markdown]
# Notamos algunos valores extraños como
#
# - "05-01"
# - "03-2021"
#
# En el primer caso no tenemos el año, en el segundo no tenemos el día. Luego, existen fechas donde el separador es "-" y en otras es "/". Tenemos también valores nan.
# Por último, el formato para algunas fechas es día-mes-año.
# Reemplazaremos los "/" por "-", colocaremos el formato año-mes-dia y cualquier campo que sea nan o que no se pueda convertir en fecha, le daremos el valor 1900-01-01 para indicar la ausencia de fecha. Eso lo haremos con la siguiente función:

# %%
def normalizar_fecha(fecha_entrada):
    '''
    Permite normalizar las fechas a un formato dd-mm-yyyy y establecer que un string que no
    tenga formato de fecha sea convertido a 1900-01-01
    
    Parámetros
    
    fecha_entrada: variable string que representa la fecha pasada desde el conjunto de datos
    
    Retorno
    
    Retorna una fecha en formato yyyy-mm-dd
    
    '''
    FECHA_NULA = pd.Timestamp("1900-01-01")
    # 1. NaN directo
    if pd.isna(fecha_entrada):
        return FECHA_NULA
    
    fecha_entrada= str(fecha_entrada).strip()
    
    #o formato dd-mm, mm-dd, dd-yyyy, mm-yyyy
    if re.fullmatch(r"\d{2}-\d{2}", fecha_entrada) or re.fullmatch(r"\d{2}-\d{4}", fecha_entrada) or re.fullmatch(r"\d{4}-\d{2}", fecha_entrada):
        return FECHA_NULA

    
    # 3. dd-mm-yyyy (con o sin hora)
    if re.match(r"^\d{2}-\d{2}-\d{4}", fecha_entrada):
        fecha = pd.to_datetime(
            fecha_entrada,
            format="%d-%m-%Y",
            errors="coerce"
        )
        return fecha.date() 

    # 4. yyyy-mm-dd (con o sin hora)
    if re.match(r"^\d{4}-\d{2}-\d{2}", fecha_entrada):
        fecha = pd.to_datetime(
            fecha_entrada,
            format="%Y-%m-%d",
            errors="coerce"
        )
        return fecha.date()

    # 5. Todo lo demás → fecha nula
    return FECHA_NULA

# %% [markdown]
# Cuando se defina la función, aplicaremos esa función a los campos fecha de los conjuntos de datos. Cuando el formato esté correcto, podemos adaptar el tipo de dato a fecha sin problemas, en caso de ser necesario, usando pd.to_datetime.

# %%
#transformamos a string para facilitar el trabajo, reemplazamos "/" por "-" y limpiamos
#los blancos
df_pato['fecha']=(
    df_pato['fecha']
    .astype(str)
    .str.replace("/","-")
    .str.strip()
)
print("El total de valores únicos para las fechas es {}".format(len(df_pato['fecha'].unique())))
# Out:
# El total de valores únicos para las fechas es 135

# %%
#aplico la función a cada fecha del dataframe
df_pato["fecha"] = df_pato["fecha"].apply(normalizar_fecha)
df_pato["fecha"].unique()
# Out:
# array([datetime.date(2020, 1, 1), datetime.date(2020, 2, 1),
#        datetime.date(2020, 3, 1), datetime.date(2020, 4, 1),
#        datetime.date(2020, 5, 1), Timestamp('1900-01-01 00:00:00'),
#        datetime.date(2020, 6, 1), datetime.date(2020, 7, 1),
#        datetime.date(2020, 8, 1), datetime.date(2020, 8, 2),
#        datetime.date(2020, 8, 5), datetime.date(2020, 9, 1),
#        datetime.date(2020, 10, 1), datetime.date(2020, 11, 1),
#        datetime.date(2020, 12, 1), datetime.date(2021, 1, 1),
#        datetime.date(2021, 2, 1), datetime.date(2021, 3, 1),
#        datetime.date(2021, 4, 1), datetime.date(2021, 5, 1),
#        datetime.date(2021, 6, 1), datetime.date(2021, 6, 2),
#        datetime.date(2021, 6, 4), datetime.date(2021, 6, 9),
#        datetime.date(2021, 6, 11), datetime.date(2021, 6, 16),
#        datetime.date(2021, 6, 25), datetime.date(2021, 6, 30),
#        datetime.date(2021, 7, 1), datetime.date(2021, 7, 8),
#        datetime.date(2021, 7, 14), datetime.date(2021, 7, 15),
#        datetime.date(2021, 7, 23), datetime.date(2021, 7, 28),
#        datetime.date(2021, 7, 30), datetime.date(2021, 7, 7),
#        datetime.date(2021, 7, 21), datetime.date(2021, 7, 2),
#        datetime.date(2021, 8, 1), datetime.date(2021, 8, 4),
#        datetime.date(2021, 8, 6), datetime.date(2021, 9, 1),
#        datetime.date(2021, 8, 12), datetime.date(2021, 8, 5),
#        datetime.date(2021, 8, 20), datetime.date(2021, 8, 18),
#        datetime.date(2021, 8, 11), datetime.date(2021, 10, 1),
#        datetime.date(2021, 11, 1), datetime.date(2021, 8, 13),
#        datetime.date(2021, 9, 3), datetime.date(2021, 11, 3),
#        datetime.date(2021, 11, 23), datetime.date(2021, 9, 17),
#        datetime.date(2021, 10, 27), datetime.date(2021, 10, 29),
#        datetime.date(2021, 10, 6), datetime.date(2021, 11, 12),
#        datetime.date(2021, 11, 24), datetime.date(2021, 11, 17),
#        datetime.date(2021, 10, 20), datetime.date(2021, 10, 13),
#        datetime.date(2021, 10, 7), datetime.date(2021, 10, 22),
#        datetime.date(2021, 11, 19), datetime.date(2021, 12, 1),
#        datetime.date(2022, 1, 1), datetime.date(2023, 1, 1),
#        datetime.date(2023, 2, 1), datetime.date(2023, 3, 1),
#        datetime.date(2023, 4, 1), datetime.date(2023, 5, 1),
#        datetime.date(2023, 6, 1), datetime.date(2023, 7, 1),
#        datetime.date(2023, 8, 1), datetime.date(2023, 9, 1),
#        datetime.date(2023, 10, 1), datetime.date(2023, 11, 1),
#        datetime.date(2023, 12, 1), datetime.date(2024, 1, 1),
#        datetime.date(2024, 2, 1), datetime.date(2024, 3, 1),
#        datetime.date(2024, 4, 1), datetime.date(2024, 5, 1),
#        datetime.date(2024, 5, 31), datetime.date(2024, 5, 29),
#        datetime.date(2024, 3, 7), datetime.date(2024, 5, 15),
#        datetime.date(2024, 5, 17), datetime.date(2024, 5, 27),
#        datetime.date(2024, 6, 1), datetime.date(2024, 6, 19),
#        datetime.date(2024, 6, 14), datetime.date(2024, 6, 12),
#        datetime.date(2024, 6, 5), datetime.date(2024, 6, 7),
#        datetime.date(2024, 6, 26), datetime.date(2024, 6, 28),
#        datetime.date(2024, 7, 1), datetime.date(2024, 7, 3),
#        datetime.date(2024, 7, 5), datetime.date(2024, 8, 1),
#        datetime.date(2024, 8, 2), datetime.date(2024, 8, 9),
#        datetime.date(2024, 8, 14), datetime.date(2024, 8, 16),
#        datetime.date(2024, 8, 28), datetime.date(2024, 8, 30),
#        datetime.date(2024, 9, 1), datetime.date(2024, 10, 1),
#        datetime.date(2024, 11, 1), datetime.date(2024, 12, 1),
#        datetime.date(2025, 1, 1), datetime.date(2025, 12, 1),
#        datetime.date(2025, 2, 1), datetime.date(2025, 3, 1),
#        datetime.date(2025, 4, 1), datetime.date(2025, 5, 1),
#        datetime.date(2025, 4, 29), datetime.date(2025, 4, 10),
#        datetime.date(2025, 4, 15), datetime.date(2025, 4, 8),
#        datetime.date(2025, 4, 22), datetime.date(2025, 4, 24),
#        datetime.date(2025, 6, 1), datetime.date(2025, 5, 15),
#        datetime.date(2025, 5, 13), datetime.date(2025, 5, 20),
#        datetime.date(2025, 5, 29), datetime.date(2025, 5, 22),
#        datetime.date(2025, 7, 1), datetime.date(2025, 8, 1)], dtype=object)

# %%
#convierto finalmente en fecha
df_pato["fecha"]=pd.to_datetime(df_pato['fecha'])
print("El total de valores únicos para las fechas despues de la limpieza: {}".format(len(df_pato['fecha'].unique())))
df_pato["fecha"].unique()
# Out:
# El total de valores únicos para las fechas despues de la limpieza: 132
# <DatetimeArray>
# ['2020-01-01 00:00:00', '2020-02-01 00:00:00', '2020-03-01 00:00:00',
#  '2020-04-01 00:00:00', '2020-05-01 00:00:00', '1900-01-01 00:00:00',
#  '2020-06-01 00:00:00', '2020-07-01 00:00:00', '2020-08-01 00:00:00',
#  '2020-08-02 00:00:00',
#  ...
#  '2025-04-22 00:00:00', '2025-04-24 00:00:00', '2025-06-01 00:00:00',
#  '2025-05-15 00:00:00', '2025-05-13 00:00:00', '2025-05-20 00:00:00',
#  '2025-05-29 00:00:00', '2025-05-22 00:00:00', '2025-07-01 00:00:00',
#  '2025-08-01 00:00:00']
# Length: 132, dtype: datetime64[ns]

# %% [markdown]
# # Analizando Las Patologías

# %% [markdown]
# Empecemos analizando las situaciones en las que tanto el código de la patología como la agrupación cie10 tienen el valor NaN. Esto es importante porque nos dice qué registro no tienen ni el código ni su agrupación, lo cual nos hace muy difícil saber qué patología fue la que se trató en la consulta.

# %%
df_pato[['patologia_desc','agrupacion_CIE10','patologia_cod']].head(10)
# Out:
#                                       patologia_desc
# 0           CONTROL DEL NIÑO SANO - CONTROL DE SALUD  \
# 1           CONTROL DEL NIÑO SANO - CONTROL DE SALUD
# 2           CONTROL DEL NIÑO SANO - CONTROL DE SALUD
# 3           CONTROL DEL NIÑO SANO - CONTROL DE SALUD
# 4           CONTROL DEL NIÑO SANO - CONTROL DE SALUD
# 5           CONTROL DEL NIÑO SANO - CONTROL DE SALUD
# 6  DIARREA Y GASTROENTERITIS DE PRESUNTO ORIGEN I...
# 7  DIARREA Y GASTROENTERITIS DE PRESUNTO ORIGEN I...
# 8  DIARREA Y GASTROENTERITIS DE PRESUNTO ORIGEN I...
# 9  DIARREA Y GASTROENTERITIS DE PRESUNTO ORIGEN I...
#
#                                     agrupacion_CIE10 patologia_cod
# 0  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z001
# 1  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z001
# 2  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z001
# 3  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z001
# 4  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z001
# 5  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z001
# 6              ENFERMEDADES INFECCIOSAS INTESTINALES           A09
# 7              ENFERMEDADES INFECCIOSAS INTESTINALES           A09
# 8              ENFERMEDADES INFECCIOSAS INTESTINALES           A09
# 9              ENFERMEDADES INFECCIOSAS INTESTINALES           A09

# %%
#df_pato.iloc[df_pato[(df_pato['agrupacion_CIE10'].isnull()) & (df_pato['patologia_cod'].isnull())].index].head()
indices=df_pato[(df_pato['agrupacion_CIE10'].isnull()) & (df_pato['patologia_cod'].isnull()) & (df_pato['patologia_desc'].isnull())].index
indices
# Out:
# Index([ 66743,  66794,  67028,  67029,  67032,  67034,  67035,  67036,  67040,
#         72174,  75017,  75167,  75168,  75169,  75170,  75171,  75172,  75173,
#         75174, 107598, 107599, 121592, 139698, 139699, 163654, 163655],
#       dtype='int64')

# %% [markdown]
# Con los índices, sabemos en cuales registros se cumple la condición. Lo que queremos es convertir los nan en "n/a" para indica la ausencia de los datos. Con esto ya sabemos de cuales registros no podremos saber la patología en cuestión.

# %%
#modifico los valores nan a "n/a" para indicar la ausencia de valores para esos campos
df_pato.iloc[indices,3:6]="n/a"
df_pato.iloc[indices]
# Out:
#        ID_SAPS                         SAPS      fecha patologia_desc
# 66743     42.0         Dr. SANTIAGO LORENZO 2021-11-01            n/a  \
# 66794     34.0               MARCELINO VERA 2021-11-01            n/a
# 67028     62.0                        PUJOL 2021-11-01            n/a
# 67029     62.0                        PUJOL 2021-11-01            n/a
# 67032     62.0                        PUJOL 2021-11-01            n/a
# 67034     62.0                        PUJOL 2021-11-01            n/a
# 67035     62.0                        PUJOL 2021-11-01            n/a
# 67036     62.0                        PUJOL 2021-11-01            n/a
# 67040     62.0                        PUJOL 2021-11-01            n/a
# 72174     32.0           DR. MANUEL CASSUSO 2021-12-01            n/a
# 75017     37.0                  DR. SUSSINI 2022-01-01            n/a
# 75167     54.0                        ITATI 2022-01-01            n/a
# 75168     54.0                        ITATI 2022-01-01            n/a
# 75169     54.0                        ITATI 2022-01-01            n/a
# 75170     54.0                        ITATI 2022-01-01            n/a
# 75171     54.0                        ITATI 2022-01-01            n/a
# 75172     54.0                        ITATI 2022-01-01            n/a
# 75173     54.0                        ITATI 2022-01-01            n/a
# 75174     54.0                        ITATI 2022-01-01            n/a
# 107598     NaN                 QUINTA FERRE 2023-09-01            n/a
# 107599     NaN                 QUINTA FERRE 2023-09-01            n/a
# 121592     NaN                  SANTA MARTA 2024-02-01            n/a
# 139698     NaN  DR. JOSE DE LOS REYES VIDAL 2024-09-01            n/a
# 139699     NaN  DR. JOSE DE LOS REYES VIDAL 2024-09-01            n/a
# 163654     NaN                  SANTA MARTA 2025-07-01            n/a
# 163655     NaN                  SANTA MARTA 2025-07-01            n/a
#
#        agrupacion_CIE10 patologia_cod id_rango_etario  consulta_cantidad
# 66743               n/a           n/a               5                 31  \
# 66794               n/a           n/a               6                  1
# 67028               n/a           n/a               3                  3
# 67029               n/a           n/a               3                  3
# 67032               n/a           n/a               6                  1
# 67034               n/a           n/a               2                  1
# 67035               n/a           n/a               3                  1
# 67036               n/a           n/a               3                  1
# 67040               n/a           n/a               4                  1
# 72174               n/a           n/a             NaN                 -1
# 75017               n/a           n/a             NaN                 -1
# 75167               n/a           n/a               2                  2
# 75168               n/a           n/a               2                  4
# 75169               n/a           n/a               3                  6
# 75170               n/a           n/a               3                  5
# 75171               n/a           n/a               5                 12
# 75172               n/a           n/a               5                  5
# 75173               n/a           n/a               6                  8
# 75174               n/a           n/a               6                  2
# 107598              n/a           n/a             NaN                 -1
# 107599              n/a           n/a             NaN                 -1
# 121592              n/a           n/a             NaN                 -1
# 139698              n/a           n/a             NaN                 -1
# 139699              n/a           n/a             NaN                 -1
# 163654              n/a           n/a             NaN                 -1
# 163655              n/a           n/a             NaN                 -1
#
#         rango_etario sexo
# 66743     20-39 AÑOS    F
# 66794     40-69 AÑOS    F
# 67028    5 - 14 AÑOS    F
# 67029    5 - 14 AÑOS    M
# 67032     40-69 AÑOS    F
# 67034     1 - 4 AÑOS    M
# 67035    5 - 14 AÑOS    F
# 67036    5 - 14 AÑOS    M
# 67040   15 - 19 AÑOS    F
# 72174            NaN  NaN
# 75017            NaN  NaN
# 75167     1 - 4 AÑOS    F
# 75168     1 - 4 AÑOS    M
# 75169    5 - 14 AÑOS    F
# 75170    5 - 14 AÑOS    M
# 75171     20-39 AÑOS    F
# 75172     20-39 AÑOS    M
# 75173     40-69 AÑOS    F
# 75174     40-69 AÑOS    M
# 107598           NaN  NaN
# 107599           NaN  NaN
# 121592           NaN  NaN
# 139698           NaN  NaN
# 139699           NaN  NaN
# 163654           NaN  NaN
# 163655           NaN  NaN

# %% [markdown]
# Ahora, buscamos los registros donde tenemos el código cie10, pero no tenemos la agrupación. Conociendo el código, podremos conocer a qué agrupación pertenece.

# %%
indices=df_pato[(df_pato['agrupacion_CIE10'].isnull()) & (df_pato['patologia_cod']).notnull()].index
df_pato.iloc[indices]
# Out:
#        ID_SAPS               SAPS      fecha patologia_desc agrupacion_CIE10
# 24480     38.0          DR. FLIER 2020-09-01            NaN              NaN  \
# 24491     38.0          DR. FLIER 2020-09-01            NaN              NaN
# 24798      NaN      DR. KORIMBLUM 2020-09-01            NaN              NaN
# 24799      NaN      DR. KORIMBLUM 2020-09-01            NaN              NaN
# 24906     75.0  DR. MAURICIO OPEN 2020-09-01            NaN              NaN
# ...        ...                ...        ...            ...              ...
# 161598     NaN         DR. PIRCHI 2025-06-01            NaN              NaN
# 161599     NaN         DR. PIRCHI 2025-06-01            NaN              NaN
# 161600     NaN         DR. PIRCHI 2025-06-01            NaN              NaN
# 163186     NaN      DR. KORIMBLUM 2025-07-01            NaN              NaN
# 166114     NaN              PUJOL 2025-08-01            NaN              NaN
#
#        patologia_cod id_rango_etario  consulta_cantidad rango_etario sexo
# 24480            R78               3                  2  5 - 14 AÑOS    M
# 24491            U19               5                  4   20-39 AÑOS    F
# 24798           K104               5                  1   20-39 AÑOS    F
# 24799           K104               6                  1   40-69 AÑOS    F
# 24906           M910               5                  1   20-39 AÑOS    F
# ...              ...             ...                ...          ...  ...
# 161598           Z71             5.0                  9   20-39 AÑOS    F
# 161599           Z71             5.0                  1   20-39 AÑOS    M
# 161600           Z71             6.0                  1   40-69 AÑOS    F
# 163186           G51             3.0                  1  5 - 14 AÑOS    F
# 166114          B084               3                  1  5 - 14 AÑOS    M
#
# [262 rows x 10 columns]

# %% [markdown]
# Notamos que tenemos el código de la patología, pero no la descripción y la agrupación. Podemos usar ciertas páginas web con esa información y, además, los datos abiertos de Corrientes también aporta un archivo con la información del código cie10. Las páginas utilizadas se encuentran en las referencias del README.
# Cargaremos el csv con los códigos cie10 para buscar los que nos faltan.

# %%
#csv con los datos de las patologías y su código cie10
df_nomen=pd.read_csv(path_file('tabla-salud-id_cie10.csv'))
df_nomen.head()
# Out:
#   ID_patologia                      TIPO DE PATOLOGIA
# 0          A00  ENFERMEDADES INFECCIOSAS INTESTINALES  \
# 1          A01  ENFERMEDADES INFECCIOSAS INTESTINALES
# 2          A02  ENFERMEDADES INFECCIOSAS INTESTINALES
# 3          A03  ENFERMEDADES INFECCIOSAS INTESTINALES
# 4          A04  ENFERMEDADES INFECCIOSAS INTESTINALES
#
#                                   Descripción
# 0                                      COLERA
# 1             FIEBRES TIFOIDEA Y PARATIFOIDEA
# 2      OTRAS INFECCIONES DEBIDAS A SALMONELLA
# 3                                  SHIGELOSIS
# 4  OTRAS INFECCIONES INTESTINALES BACTERIANAS

# %% [markdown]
# El problema es que hay códigos cie10 que no figuran en el documento de referencia. Así que usaremos otras fuentes para conseguir la información. Esta fuente proviene de un buscador para las patología según su código cie10.
# Para saber qué códigos cie10 no están presentes, compararemos qué códigos están presentes en el conjunto de datos de la patologías y los códigos presentes en el archivo con los datos de los códigos cie10. Con esta comparación sabremos qué códigos están ausentes en el archivo de códigos cie10. Estos códigos los buscaremos en páginas externas y, posteriormente, usaremos esos datos para limpiar los datos.

# %%
#obtenemos los códigos cie10 de la tablas de consultas y convierto la lista en un conjunto
set_cod_cie_pato=set(df_pato['patologia_cod'].unique())
#obtenemos los códigos cie10 del documento de referencia y convierto la lista en un conjunto
set_cod_cie=set(df_nomen['ID_patologia'].unique())
#aplico la diferencia entre los códigos cie10 de las patologías y los códigos cie10 de la tabla de códigos
#el resultado tendrá los códigos cie10 que están en el conjunto de datos de patologías, pero no en la tabla de
#códigos cie10.
display(set_cod_cie_pato.difference(set_cod_cie))
# Out:
# {'A071',
#  'B11',
#  'B20',
#  'B84',
#  'C61',
#  'E027',
#  'E039',
#  'E08',
#  'E444',
#  'F441',
#  'F450',
#  'G510',
#  'H13',
#  'H15',
#  'H650',
#  'H660',
#  'H67',
#  'I499',
#  'I519',
#  'I639',
#  'I959',
#  'J09',
#  'J12',
#  'J81',
#  'K080',
#  'K104',
#  'K295',
#  'K746',
#  'K760',
#  'K819',
#  'L739',
#  'M515',
#  'M624',
#  'M67',
#  'M796',
#  'M910',
#  'N11',
#  'N12',
#  'N391',
#  'N481',
#  'N951',
#  'R011',
#  'R07',
#  'R088',
#  'R252',
#  'R702',
#  'R78',
#  'S019',
#  'S06',
#  'S401',
#  'S49',
#  'S69',
#  'S71',
#  'S89',
#  'S99',
#  'T171',
#  'T418',
#  'T670',
#  'T74',
#  'T784',
#  'U19',
#  'U59',
#  'U60',
#  'U61',
#  'U62',
#  'U63',
#  'U64',
#  'U67',
#  'V206',
#  'Y20',
#  'Y30',
#  'Y45',
#  'Z14',
#  'Z300',
#  'Z38',
#  'a04',
#  'a09',
#  'a51',
#  'a53',
#  'a59',
#  'b01',
#  'b02',
#  'b08',
#  'b30',
#  'b36',
#  'b373',
#  'b49',
#  'b68',
#  'b82',
#  'b85',
#  'b86',
#  'd50',
#  'e03',
#  'e05',
#  'e10',
#  'e11',
#  'e14',
#  'e441',
#  'e46',
#  'e66',
#  'e78',
#  'f29',
#  'f40',
#  'f51',
#  'f91',
#  'g43',
#  'g47',
#  'h00',
#  'h10',
#  'h400',
#  'h60',
#  'h65',
#  'h66',
#  'h920',
#  'i10',
#  'i15',
#  'i20',
#  'i84',
#  'i95',
#  'j00',
#  'j01',
#  'j02',
#  'j03',
#  'j04',
#  'j06',
#  'j10',
#  'j11',
#  'j18',
#  'j20',
#  'j21',
#  'j22',
#  'j30',
#  'j39',
#  'j45',
#  'j95',
#  'k007',
#  'k02',
#  'k03',
#  'k05',
#  'k088',
#  'k10',
#  'k29',
#  'k30',
#  'k52',
#  'k590',
#  'l01',
#  'l02',
#  'l03',
#  'l089',
#  'l20',
#  'l22',
#  'l23',
#  'l30',
#  'l40',
#  'l50',
#  'l93',
#  'm13',
#  'm17',
#  'm255',
#  'm54',
#  'm542',
#  'm545',
#  'm62',
#  'n/a',
#  'n30',
#  'n390',
#  'n76',
#  'n910',
#  'n912',
#  'n93',
#  'n96',
#  'r02',
#  'r05',
#  'r06',
#  'r060',
#  'r070',
#  'r071',
#  'r074',
#  'r10',
#  'r101',
#  'r102',
#  'r104',
#  'r11',
#  'r30',
#  'r42',
#  'r50',
#  'r51',
#  'r53',
#  'r56',
#  'r70',
#  's90',
#  't00',
#  't01',
#  't14',
#  't141',
#  't78',
#  'u204',
#  'u51',
#  'w19',
#  'w99',
#  'x25',
#  'z000',
#  'z001',
#  'z003',
#  'z014',
#  'z027',
#  'z26',
#  'z30',
#  'z34',
#  'z392'}

# %% [markdown]
# Lo que haré es crear un diccionario cuyas claves son los códigos cie10 y los valores contienen las descripciones de las patologías según ese código. Luego, emplearé ese diccionario para completar los valores faltantes. Este es un primer enfoque, ya que puede haber algunos códigos que se escapen. Y se realiza así porque son pocos valores, el trabajo de hacer esto es más rápido que ir reformateando los csv donde están los códigos cie10 obtenidos de otras fuentes. Posteriormente, se puede completar el diccionario con los código faltantes.
# Aunque debe tenerse en cuenta que ese documento deberá reformatearse para futuras actualizaciones, ya que automatizaría mejor el proceso.

# %%
#el diccionario contiene los códigos cie10 y su agrupación que faltan en el conjunto de datos de las patologías.
#Los casos de códigos con 'n/a' son patologías cuyo código cie10 no encontramos.
map_cie_cod={
    'A071':'Giardiasis [lambliasis]',
    'B11':'n/a',
    "B82":"Parasitosis intestinal, sin otra especificación",
    'B20':'Enfermedad por virus de la inmunodeficiencia humana [VIH], resultante en enfermedades infecciosas y parasitarias',
    'B84':'n/a',
    'B084':'Estomatitis vesicular enteroviral con exantema',
    'C61':'Tumor maligno de la próstata',
    'E039':'Hipotiroidismo',
    "E027":"n/a",
    'E08':'n/a',
    'E444':'Desnutrición proteicocalórica de grado moderado y leve',
    'F441':'Fuga disociativa',
    'F450':'Trastorno de somatización',
    'G510':'Parálisis de Bell',
    "G51":'Trastornos del nervio facial',
    'H13':'Trastornos de la conjuntiva en enfermedades clasificadas en otra parte',
    'H15':'Trastornos de la esclerótica',
    'H650':'Otitis media aguda serosa',
    'H660':'Otitis media supurativa aguda',
    'H67':'Otitis media en enfermedades clasificadas en otra parte',
    'I499':'Arritmia cardíaca, no especificada',
    'I59':'n/a',
    'I519':'Enfermedad cardíaca, no especificada',
    'I639':'Infarto cerebral, no especificado',
    'I959':'Hipotensión, no especificada',
    'J09':'Influenza debida a virus de la influenza aviar identificado',
    'J12':'	Neumonía viral, no clasificada en otra parte',
    'J81':'Edema pulmonar',
    'K080':'Exfoliación de los dientes debida a causas sistémicas',
    'K104':'n/a',
    'K295':'Gastritis crónica, no especificada',
    'K746':'Otras cirrosis del hígado y las no especificadas',
    'K760':'Degeneración grasa del hígado, no clasificada en otra parte',
    'K819':'Colecistitis, no especificada',
    'L739':'Trastorno folicular, no especificado',
    'M515':'n/a',
    'M624':'Contractura muscular',
    'M67':'Otros trastornos de la sinovia y del tendón',
    'M796':'Dolor en miembro',
    'M910':'Osteocondrosis juvenil de la pelvis',
    'N11':'Nefritis tubulointersticial crónica',
    'N12':'Nefritis tubulointersticial, no especificada como aguda o crónica',
    'N391':'Proteinuria persistente, n o especificada',
    'N481':'Balanopostitis',
    'N951':'Estados menopáusicos y climatéricos femeninos',
    'R011':'Soplo cardíaco, no especificado',
    'R07':'Dolor de garganta y en el pecho',
    'R088':'n/a',
    'R252':'Calambres y espasmos',
    'R702':'n/a',
    'R78':'Hallazgo de drogas y otras sustancias que normalmente no se encuentran en la sangre',
    'S019':'Herida de la cabeza, parte no especificada',
    'S06':'Traumatismo intracraneal',
    "S401":'n/a',
    "S49":"Otros traumatismos y los no especificados del hombro y del brazo",
    "S69":"Otros traumatismos y los no especificados de la muñeca y de la mano",
    "S71":"Herida de la cadera y del muslo",
    "S89":"Otros traumatismos y los no especificados de la pierna",
    "S99":"Otros traumatismos y los no especificados del pie y del tobillo",
    "T171":"Cuerpo extraño en el orificio nasal",
    "T418":"n/a",
    "T670":"Golpe de calor e insolación",
    "T74":"Síndrome del maltrato",
    "T784":"Alergia no especificada",
    "U19":"n/a",
    "U59":"n/a",
    "U60":"n/a",
    "U61":"n/a",
    "U62":"n/a",
    "U63":"n/a",
    "U64":"n/a",
    "U67":"n/a",
    "V206":"n/a",
    "Y20":"Ahorcamiento, estrangulamiento y sofocación, de intención no determinada",
    "Y30":"Caída, salto o empujón desde lugar elevado, de intención no determinada",
    "Z14":"n/a",
    "Y40":"Efectos adversos de antibióticos sistémicos",
    "Y45":"Efectos adversos de drogas analgésicas, antipiréticas y antiinflamatorias",
    "Z300":"Consejo y asesoramiento general sobre la anticoncepción",
    "Z38":"Nacidos vivos según lugar de nacimiento",
    "Z71":"Personas en contacto con los servicios de salud por otras consultas y consejos médicos, no clasificados en otra parte",
    "Z73":"	Problemas relacionados con dificultades con el modo de vida",
    "nan":"n/a"

}

# %%
#recorro el índice de los datos donde existe el código cie10, pero no existe la explicación
#del código.
#En la columna donde debe ir la explicación de la patología según el código, coloco
#el valor del diccionario, ya que la clave es el código cie10
#{clave:valor}
#fila i y en la columna 4, que es el de la agrupación_cie10
for i in indices:
    df_pato.iloc[i,4]=map_cie_cod[df_pato.iloc[i,5]].strip()

# %%
df_pato.iloc[indices]
# Out:
#        ID_SAPS               SAPS      fecha patologia_desc
# 24480     38.0          DR. FLIER 2020-09-01            NaN  \
# 24491     38.0          DR. FLIER 2020-09-01            NaN
# 24798      NaN      DR. KORIMBLUM 2020-09-01            NaN
# 24799      NaN      DR. KORIMBLUM 2020-09-01            NaN
# 24906     75.0  DR. MAURICIO OPEN 2020-09-01            NaN
# ...        ...                ...        ...            ...
# 161598     NaN         DR. PIRCHI 2025-06-01            NaN
# 161599     NaN         DR. PIRCHI 2025-06-01            NaN
# 161600     NaN         DR. PIRCHI 2025-06-01            NaN
# 163186     NaN      DR. KORIMBLUM 2025-07-01            NaN
# 166114     NaN              PUJOL 2025-08-01            NaN
#
#                                          agrupacion_CIE10 patologia_cod
# 24480   Hallazgo de drogas y otras sustancias que norm...           R78  \
# 24491                                                 n/a           U19
# 24798                                                 n/a          K104
# 24799                                                 n/a          K104
# 24906                 Osteocondrosis juvenil de la pelvis          M910
# ...                                                   ...           ...
# 161598  Personas en contacto con los servicios de salu...           Z71
# 161599  Personas en contacto con los servicios de salu...           Z71
# 161600  Personas en contacto con los servicios de salu...           Z71
# 163186                       Trastornos del nervio facial           G51
# 166114     Estomatitis vesicular enteroviral con exantema          B084
#
#        id_rango_etario  consulta_cantidad rango_etario sexo
# 24480                3                  2  5 - 14 AÑOS    M
# 24491                5                  4   20-39 AÑOS    F
# 24798                5                  1   20-39 AÑOS    F
# 24799                6                  1   40-69 AÑOS    F
# 24906                5                  1   20-39 AÑOS    F
# ...                ...                ...          ...  ...
# 161598             5.0                  9   20-39 AÑOS    F
# 161599             5.0                  1   20-39 AÑOS    M
# 161600             6.0                  1   40-69 AÑOS    F
# 163186             3.0                  1  5 - 14 AÑOS    F
# 166114               3                  1  5 - 14 AÑOS    M
#
# [262 rows x 10 columns]

# %%
#luego, las descripciones de patologías que sean nulas, les coloco el valor 'n/a'
#estas descripciones no están relacionados directamente con el código cie10 y su agrupación, según las
#fuentes consultadas. Creemos que es un detalle propio que se le da
# en los saps, accesorio a la explicación de cie10. Así que los dejamos en 'n/a'
df_pato.iloc[df_pato[df_pato['patologia_desc'].isnull()].index,3]='n/a'
df_pato.isnull().sum()
# Out:
# ID_SAPS              100777
# SAPS                   1054
# fecha                     0
# patologia_desc            0
# agrupacion_CIE10          0
# patologia_cod             0
# id_rango_etario        1066
# consulta_cantidad         0
# rango_etario           1072
# sexo                   1148
# dtype: int64

# %% [markdown]
# # Trabajando con los rangos etarios
#
# Primero, revisemos los valores únicos para los rangos etarios.

# %%
df_pato['rango_etario'].unique()
# Out:
# array(['< 1 AÑO', '1 - 4 AÑOS', '5 - 14 AÑOS', '15 - 19 AÑOS',
#        '20-39 AÑOS', '40-69 AÑOS', '>=70 AÑOS', '#REF!', nan],
#       dtype=object)

# %% [markdown]
# Busquemos los indices donde figuren "#REF!" y "nan". Esos valores los cambiaremos a "n/a"

# %%
index_etario=df_pato[(df_pato['rango_etario'].astype(str)=='nan') | (df_pato['rango_etario']=='#REF!')].index
df_pato.iloc[index_etario].head()
# Out:
#       ID_SAPS                         SAPS      fecha
# 674       NaN           DR. ANIBAL MALVIDO 2020-01-01  \
# 7231     71.0               VILLA CHIQUITA 2020-02-01
# 24685    48.0  DR. JOSE DE LOS REYES VIDAL 2020-09-01
# 32653    86.0                PASO MARTINEZ 2020-12-01
# 33356     NaN           DR. ANIBAL MALVIDO 2021-01-01
#
#                                           patologia_desc
# 674                    ANEMIAS POR DEFICIENCIA DE HIERRO  \
# 7231                                  DERMATITIS ATOPICA
# 24685                             GASTRITIS Y DUODENITIS
# 32653     CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO
# 33356  TRASTORNOS DE LOS TEJIDOS BLANDOS EN ENFERMEDA...
#
#                                         agrupacion_CIE10 patologia_cod
# 674                                ANEMIAS NUTRICIONALES           D50  \
# 7231                                 DERMATITIS Y ECZEMA           L20
# 24685  ENFERMEDADES DEL ESOFAGO, DEL ESTOMAGO Y DEL D...           K29
# 32653  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000
# 33356            OTROS TRASTORNOS DE LOS TEJIDOS BLANDOS           M73
#
#       id_rango_etario  consulta_cantidad rango_etario sexo
# 674                 1                  2        #REF!    F
# 7231                3                  1        #REF!    M
# 24685              ||                  1          NaN    M
# 32653               4                  7        #REF!    F
# 33356               9                  1          NaN    F

# %% [markdown]
# Ahora, queremos que la columna "rango_etario" tenga el valor 'n/a' para los índices encontrados. Eso lo hacemos de la siguiente forma

# %%
#Cambiamos los valores del rango etario con NaN en 'n/a'. A la vez, cambio también el campo id_rango_etario
#pertinente a 'n/a'. Esto es así porque un rango etario con 'n/a' no debería tener un id que lo identifique, a priori.
df_pato.iloc[index_etario,6:9:2]='n/a'
df_pato.iloc[index_etario]
# Out:
#        ID_SAPS                         SAPS      fecha
# 674        NaN           DR. ANIBAL MALVIDO 2020-01-01  \
# 7231      71.0               VILLA CHIQUITA 2020-02-01
# 24685     48.0  DR. JOSE DE LOS REYES VIDAL 2020-09-01
# 32653     86.0                PASO MARTINEZ 2020-12-01
# 33356      NaN           DR. ANIBAL MALVIDO 2021-01-01
# ...        ...                          ...        ...
# 150744     NaN            DR. MAURICIO OPEN 2025-02-01
# 155531     NaN                    ESPERANZA 2025-04-01
# 163654     NaN                  SANTA MARTA 2025-07-01
# 163655     NaN                  SANTA MARTA 2025-07-01
# 165512     NaN                    ESPERANZA 2025-08-01
#
#                                            patologia_desc
# 674                     ANEMIAS POR DEFICIENCIA DE HIERRO  \
# 7231                                   DERMATITIS ATOPICA
# 24685                              GASTRITIS Y DUODENITIS
# 32653      CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO
# 33356   TRASTORNOS DE LOS TEJIDOS BLANDOS EN ENFERMEDA...
# ...                                                   ...
# 150744                  ARTRITIS REUMATOIDES SEROPOSITIVA
# 155531           DIABETES MELLITUS NO INSULINODEPENDIENTE
# 163654                                                n/a
# 163655                                                n/a
# 165512                                     OTRAS ARTROSIS
#
#                                          agrupacion_CIE10 patologia_cod
# 674                                 ANEMIAS NUTRICIONALES           D50  \
# 7231                                  DERMATITIS Y ECZEMA           L20
# 24685   ENFERMEDADES DEL ESOFAGO, DEL ESTOMAGO Y DEL D...           K29
# 32653   PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000
# 33356             OTROS TRASTORNOS DE LOS TEJIDOS BLANDOS           M73
# ...                                                   ...           ...
# 150744                            ARTROPATIAS INFECCIOSAS           M05
# 155531                                  DIABETES MELLITUS           E11
# 163654                                                n/a           n/a
# 163655                                                n/a           n/a
# 165512                                           ARTROSIS           M19
#
#        id_rango_etario  consulta_cantidad rango_etario sexo
# 674                n/a                  2          n/a    F
# 7231               n/a                  1          n/a    M
# 24685              n/a                  1          n/a    M
# 32653              n/a                  7          n/a    F
# 33356              n/a                  1          n/a    F
# ...                ...                ...          ...  ...
# 150744             n/a                 -1          n/a  NaN
# 155531             n/a                 -1          n/a  NaN
# 163654             n/a                 -1          n/a  NaN
# 163655             n/a                 -1          n/a  NaN
# 165512             n/a                  2          n/a    F
#
# [1078 rows x 10 columns]

# %%
#reviso la situación de los nulos hasta el momento
df_pato.isnull().sum()
# Out:
# ID_SAPS              100777
# SAPS                   1054
# fecha                     0
# patologia_desc            0
# agrupacion_CIE10          0
# patologia_cod             0
# id_rango_etario           0
# consulta_cantidad         0
# rango_etario              0
# sexo                   1148
# dtype: int64

# %% [markdown]
# # Analizando el id para el rango etario
#
# Empecemos viendo los valores que posee

# %%
display(df_pato['rango_etario'].unique())
display(df_pato['id_rango_etario'].unique())
display(df_pato[['rango_etario','id_rango_etario']].drop_duplicates().head(10))
# Out:
# array(['< 1 AÑO', '1 - 4 AÑOS', '5 - 14 AÑOS', '15 - 19 AÑOS',
#        '20-39 AÑOS', '40-69 AÑOS', '>=70 AÑOS', 'n/a'], dtype=object)
# array([1, 2, 3, 4, 5, 6, 7, 'n/a', '6', '2', '3', '4', '5', '7', '1'],
#       dtype=object)
#      rango_etario id_rango_etario
# 0         < 1 AÑO               1
# 2      1 - 4 AÑOS               2
# 4     5 - 14 AÑOS               3
# 10   15 - 19 AÑOS               4
# 11     20-39 AÑOS               5
# 12     40-69 AÑOS               6
# 13      >=70 AÑOS               7
# 674           n/a             n/a
# 676       < 1 AÑO               2
# 678    1 - 4 AÑOS               3

# %% [markdown]
# Vemos que es una numeración estandar de enteros ascendentes. Hay casos en que está mal clasificado, por ejemplo, hay registros que indican que el rango etario 1-4 años tiene el id=2, y otros que indican que el mismo rango etario tiene el id=3. Como no parece haber un código muy elaborado, podemos establecer el siguiente criterio:
# 1. < 1 año
# 2. 1-4 años
# 3. 5-14 años
# 4. 15-19 años
# 5. 20-39 años
# 6. 40-69 años
# 7. $>=70 años$
#
# Luego:-1 representa el 'n/a'.
# Podemos crear un diccionario y usarlo para mapear el campo id_rango_etario.
# Antes de eso, analizaremos los casos en que el id_rango_etario no sea nulo y el rango etario si lo sea.

# %%
df_pato[(df_pato['id_rango_etario'].notnull()) & (df_pato['rango_etario']).isnull()]
# Out:
# Empty DataFrame
# Columns: [ID_SAPS, SAPS, fecha, patologia_desc, agrupacion_CIE10, patologia_cod, id_rango_etario, consulta_cantidad, rango_etario, sexo]
# Index: []

# %% [markdown]
# El resultado anterior nos muestra que no tenemos casos donde tengamos un id_rango_etario válido. Si fuera así, podríamos establecer el rango etario usando el id. Pero como no hay con id válidos, aplicamos la limpieza indicada anteriormente.

# %%
dic_rango_etario={
    '< 1 AÑO':1,
    '1 - 4 AÑOS':2, 
    '5 - 14 AÑOS':3, 
    '15 - 19 AÑOS':4,
    '20-39 AÑOS':5, 
    '40-69 AÑOS':6, 
    '>=70 AÑOS':7, 
    'n/a':-1
}

df_pato['id_rango_etario']=df_pato['rango_etario'].str.strip().replace(dic_rango_etario)
df_pato['id_rango_etario'].unique()
# Out:
# array([ 1,  2,  3,  4,  5,  6,  7, -1], dtype=int64)

# %% [markdown]
# En el resultado final vemos cómo ahora sólo tenemos esos 8 valores, a pesar de que le pedimos que nos de 10 resultados usando head(). Esto nos dice que ahora están todos homologados respecto del rango etario y su id.

# %%
df_pato.isnull().sum()
# Out:
# ID_SAPS              100777
# SAPS                   1054
# fecha                     0
# patologia_desc            0
# agrupacion_CIE10          0
# patologia_cod             0
# id_rango_etario           0
# consulta_cantidad         0
# rango_etario              0
# sexo                   1148
# dtype: int64

# %% [markdown]
# # Analizando El Campo Sexo
#
# Nuevamente, empecemos revisando los datos únicos en ese campo.

# %%
df_pato['sexo'].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %% [markdown]
# Una vez más, tenemos nan. Lo que haremos es mapear los resultados: 'F' pasará a ser 'Femenino','M' 'Masculino' y nan a 'n/a'.

# %%
df_pato['sexo']=(
    df_pato['sexo']
    .astype(str)
    .map({'F':'Femenino','M':'Masculino','nan':'n/a','Femenino':'Femenino','Masculino':'Masculino'})
)
display(df_pato['sexo'].unique())
df_pato.isnull().sum()
# Out:
# array(['Femenino', 'Masculino', 'n/a'], dtype=object)
# ID_SAPS              100777
# SAPS                   1054
# fecha                     0
# patologia_desc            0
# agrupacion_CIE10          0
# patologia_cod             0
# id_rango_etario           0
# consulta_cantidad         0
# rango_etario              0
# sexo                      0
# dtype: int64

# %% [markdown]
# # Analizando los id de los SAPS y los nombres de los mismos
#
# Empecemos viendo los valores únicos para los SAPS y los valores únicos para id_saps

# %%
display(df_pato['SAPS'].unique())
display(df_pato['ID_SAPS'].unique())
display(len(df_pato['SAPS'].unique()))
# Out:
# array(['Dr. CALMANASH', 'DR. GUILLERMO RAWSON', 'SAPUCAY', 'CICHERO',
#        'DR MANUEL A. GONZALEZ', 'DR. ALBERTO LIFSCHITZ',
#        'DR. ANIBAL MALVIDO', 'DR. BENJAMIN SERRANO', 'DR. FLIER',
#        'DR. JOSE DE LOS REYES VIDAL', 'DR. KORIMBLUM',
#        'DR. MANUEL CASSUSO', 'DR. MAURICIO OPEN', 'DR. PEDRO BLUGERMAN',
#        'DR. PIRCHI', 'DR. ROSSI CANDIA', 'Dr. SANTIAGO LORENZO',
#        'DR. SEMPER', 'DR. SUSSINI', 'ESPERANZA', 'GDOR. ELIAS GALVAN',
#        'GÜEMES', 'ITATI', 'MARCELINO VERA', 'PASO MARTINEZ',
#        'PRIMERA JUNTA', 'PUJOL', 'QUINTA FERRE', 'RIO PARANA',
#        'SAN MARCOS', 'SANTA MARGARITA', 'SANTA MARTA', 'VILLA CHIQUITA',
#        'VILLA GARCIA', 'DR. CHERCOFF', 'SANTA CATALINA',
#        'OPERATIVOS TERRITORIALES', nan], dtype=object)
# array([45.0, 47.0, 90.0, 76.0, 41.0, 88.0, nan, 49.0, 38.0, 48.0, 32.0,
#        75.0, 91.0, 58.0, 82.0, 42.0, 37.0, 36.0, 31.0, 54.0, 34.0, 86.0,
#        69.0, 62.0, 79.0, 46.0, 73.0, 85.0, 89.0, 71.0, 70.0, 51.0, 127.0,
#        99.0, '82', '42', '36', '31', '54', '34', '99', '86', '69', '62',
#        '79', '46', '73', '127', '85', '89', '90', '71', '70', '76', '41',
#        '88', '49', '45', '51', '38', '47', '48', '32', '75', '91', '58',
#        '37', '#REF!'], dtype=object)
# 38

# %% [markdown]
# Vemos que tenemos 'nan' para ambos y '#REF!' para los id. Busquemos los casos donde no tengamos ni id ni nombre del saps. Para estos casos, reemplazaremos 'nan' y '#REF!' por 'n/a' para indicar la ausencia de valores.

# %%
indices_saps=df_pato[(df_pato['ID_SAPS'].isnull()) & (df_pato['SAPS'].isnull())].index
df_pato.iloc[indices_saps].head()
# Out:
#       ID_SAPS SAPS      fecha                                  patologia_desc
# 77276     NaN  NaN 2023-01-01  CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO  \
# 77277     NaN  NaN 2023-01-01  CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO
# 77278     NaN  NaN 2023-01-01  CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO
# 77279     NaN  NaN 2023-01-01  CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO
# 77280     NaN  NaN 2023-01-01  CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO
#
#                                         agrupacion_CIE10 patologia_cod
# 77276  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000  \
# 77277  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000
# 77278  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000
# 77279  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000
# 77280  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000
#
#        id_rango_etario  consulta_cantidad rango_etario sexo
# 77276               -1                 -1          n/a  n/a
# 77277               -1                 -1          n/a  n/a
# 77278               -1                 -1          n/a  n/a
# 77279               -1                 -1          n/a  n/a
# 77280               -1                 -1          n/a  n/a

# %%
#para los casos donde no haya id_saps ni saps (ni id, ni nombre del saps)
#rellenamos ambos campos con 'n/a' para indicar ausencia de datos
df_pato.iloc[indices_saps,0:2]='n/a'
df_pato.iloc[indices_saps].head()
# Out:
#       ID_SAPS SAPS      fecha                                  patologia_desc
# 77276     n/a  n/a 2023-01-01  CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO  \
# 77277     n/a  n/a 2023-01-01  CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO
# 77278     n/a  n/a 2023-01-01  CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO
# 77279     n/a  n/a 2023-01-01  CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO
# 77280     n/a  n/a 2023-01-01  CONTROL DE SALUD: EXAMEN MEDICO GENERAL ADULTO
#
#                                         agrupacion_CIE10 patologia_cod
# 77276  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000  \
# 77277  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000
# 77278  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000
# 77279  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000
# 77280  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z000
#
#        id_rango_etario  consulta_cantidad rango_etario sexo
# 77276               -1                 -1          n/a  n/a
# 77277               -1                 -1          n/a  n/a
# 77278               -1                 -1          n/a  n/a
# 77279               -1                 -1          n/a  n/a
# 77280               -1                 -1          n/a  n/a

# %%
df_pato.isnull().sum()
# Out:
# ID_SAPS              99723
# SAPS                     0
# fecha                    0
# patologia_desc           0
# agrupacion_CIE10         0
# patologia_cod            0
# id_rango_etario          0
# consulta_cantidad        0
# rango_etario             0
# sexo                     0
# dtype: int64

# %% [markdown]
# Analicemos lo siguiente para la imputación de datos. La cuestión es que habrá SAPS que sí tienen número de id, y habrá otros que no. Analizando los datos para cada SAPS, hay algunos registros que tienen el id en entero y el mismo id en string. Esto se debe seguro a errores de ingreso de datos: algunas veces se colocó 1 y otras veces se colocó '1'. Entonces, tomaremos los valores único para el campo SAPS que nos dará los nombres de cada SAPS y algún valor 'n/a' de la imputación anterior.
# Luego, usando esos nombres, filtraremos el dataframe. Para ese filtro obtenemos los valores únicos de id. Eso nos dará un arreglo con los valores enteros y de string (que es el mismo valor, pero con diferente tipo de dato) o nos dará nan.
# Cuando obtengamos el unique para cada nombre, nos retornará un arreglo. Tomamos el primer valor de ese arreglo, y ese será el valor del id. Pero, antes de realizar eso, transformaremos los valores nan a -1 para indicar que no tenemos id para ese SAPS. Igual, posteriormente se le dará una clave subrogada al crear el esquema estrella.
# Pero otro problema más es que tenemos un archivo csv con datos accesorios de los saps: dirección, barrio, teléfono de contacto, etc. Ese csv no tiene los id de los saps y los nombres de los saps difieren con el nombre que está registrado en el archivo de consultas. Entonces, como son pocos nombres, haremos que la tabla de consultas tenga el mismo nombre para los saps usando un diccionario para el mapeo.

# %%
#creamos el diccionario para unificar los nombres y realizar el proceso
dict_transformacion_saps={
"Dr. CALMANASH": "Dr. Saul Calmanash",
"DR. GUILLERMO RAWSON": "Dr. Guillermo Rawson",
"SANTA RITA":"Dr. Jose de los Reyes Vidal",
"RAWSON":"Dr. Guillermo Rawson",
"Cichero": "Dr. Romilio Monzón",
"CICHERO":"Dr. Romilio Monzón",
"Dr. ROMILIO MONZÓN":"Dr. Romilio Monzón",
"CAÑADA QUIROZ":"Dr. Marcelino Vera",
"DR MANUEL A. GONZALEZ":"Dr. Manuel Gonzalez",
"DR. ALBERTO LIFSCHITZ":"Dr. Lifschitz",
"DR. ANIBAL MALVIDO":"Dr. Anibal Malvido",
"DR. BENJAMIN SERRANO":"Dr. Benjamin Serrano",
"DR. FLIER": "Dr. JC Benitez Suarez",
'LOMAS':"Dr. JC Benitez Suarez",
"DR. JOSE DE LOS REYES VIDAL":"Dr. Jose de los Reyes Vidal",
"DR. KORIMBLUM": "Dr. Korimblum",
"DR. MANUEL CASSUSO":"Dr. Manuel Cassuso",
"DR. MAURICIO OPEN": "Dr. Mauricio Open",
"DR. PEDRO BLUGERMAN":"Dr. Pedro Blugerman",
"DR. PIRCHI":"Dr. Oscar Pirchi",
"DR. ROSSI CANDIA":"Dr. Miguel Rossi Candia",
"Dr. SANTIAGO LORENZO":"Dr. Santiago Lorenzo",
"DR. SEMPER":"Dr. Semper",
"DR. SUSSINI":"Dr. Sussini",
"ESPERANZA":"Esperanza",
"GDOR. ELIAS GALVAN":"Dr. Elias Galvan",
"GÜEMES":"Guemes",
"ITATI":"Itati",
"MARCELINO VERA":"Dr. Marcelino Vera",
"PASO MARTINEZ":"Paso Martinez",
"PRIMERA JUNTA":"Primera Junta",
"PUJOL":"Pujol",
"QUINTA FERRE":"Quinta Ferre",
"RIO PARANA":"Rio Parana",
"SAN MARCOS":"San Marcos",
"SANTA MARGARITA":"Santa Margarita",
"SANTA MARTA":"Santa Marta",
"VILLA CHIQUITA":"Villa Chiquita",
"VILLA GARCIA":"Villa Garcia",
"DR. CHERCOFF":"Dr. Juan Chercoff",
"SANTA CATALINA":"Santa Catalina",
"OPERATIVOS TERRITORIALES":"OPERATIVO TERRITORIALES",
"n/a":"n/a",
"CENTRO DE DIST. DE VACUNAS":"Centro de distribucion de Vacunas",
"SAPUCAY":"Sapucay"
}

#aplico una homogeneidad en los nombres
df_pato['SAPS']=df_pato['SAPS'].replace(dict_transformacion_saps)

# %%
#obtengo los valores únicos de los nombres de los saps
saps=df_pato['SAPS'].unique()
#reviso los valores únicos de los id para cada nombre de saps
for nom in saps:
    display("Saps:{}-Ids:{}".format(nom,df_pato[df_pato['SAPS']==nom]['ID_SAPS'].unique()))
# Out:
# "Saps:Dr. Saul Calmanash-Ids:[45.0 '45' nan]"
# "Saps:Dr. Guillermo Rawson-Ids:[47.0 '47']"
# "Saps:Sapucay-Ids:[90.0 '90' nan]"
# "Saps:Dr. Romilio Monzón-Ids:[76.0 '76' nan]"
# "Saps:Dr. Manuel Gonzalez-Ids:[41.0 '41' nan]"
# "Saps:Dr. Lifschitz-Ids:[88.0 '88' nan]"
# 'Saps:Dr. Anibal Malvido-Ids:[nan]'
# "Saps:Dr. Benjamin Serrano-Ids:[49.0 '49' nan]"
# "Saps:Dr. JC Benitez Suarez-Ids:[38.0 '38' nan]"
# "Saps:Dr. Jose de los Reyes Vidal-Ids:[48.0 '48' nan]"
# 'Saps:Dr. Korimblum-Ids:[nan]'
# "Saps:Dr. Manuel Cassuso-Ids:[32.0 '32' nan]"
# "Saps:Dr. Mauricio Open-Ids:[75.0 '75' nan]"
# "Saps:Dr. Pedro Blugerman-Ids:[91.0 '91' nan]"
# "Saps:Dr. Oscar Pirchi-Ids:[58.0 '58' nan]"
# "Saps:Dr. Miguel Rossi Candia-Ids:[82.0 '82' nan]"
# "Saps:Dr. Santiago Lorenzo-Ids:[42.0 '42' nan]"
# 'Saps:Dr. Semper-Ids:[nan]'
# "Saps:Dr. Sussini-Ids:[37.0 '37' nan]"
# "Saps:Esperanza-Ids:[36.0 '36' nan]"
# "Saps:Dr. Elias Galvan-Ids:[31.0 '31' '#REF!' nan]"
# 'Saps:Guemes-Ids:[nan]'
# "Saps:Itati-Ids:[54.0 '54' nan]"
# "Saps:Dr. Marcelino Vera-Ids:[34.0 '34' nan]"
# "Saps:Paso Martinez-Ids:[86.0 '86' nan]"
# "Saps:Primera Junta-Ids:[69.0 '69']"
# "Saps:Pujol-Ids:[62.0 '62' nan]"
# "Saps:Quinta Ferre-Ids:[79.0 '79' nan]"
# "Saps:Rio Parana-Ids:[46.0 '46' nan]"
# "Saps:San Marcos-Ids:[73.0 '73' nan]"
# "Saps:Santa Margarita-Ids:[85.0 '85' nan]"
# "Saps:Santa Marta-Ids:[89.0 '89' nan]"
# "Saps:Villa Chiquita-Ids:[71.0 '71' nan]"
# "Saps:Villa Garcia-Ids:[70.0 '70' nan]"
# "Saps:Dr. Juan Chercoff-Ids:[51.0 '51' nan]"
# "Saps:Santa Catalina-Ids:[127.0 '127' nan]"
# "Saps:OPERATIVO TERRITORIALES-Ids:[99.0 '99' nan]"
# "Saps:n/a-Ids:['n/a']"

# %% [markdown]
# Notamos que hay saps que tienen dos numeros (que son iguales, pero con diferente tipo de datos): uno es un entero y otro un string. Pero, ese nan al final nos está diciendo que hay registros con el nombre del SAPS pero sin su código. Por lo tanto, lo que haremos es reemplazar todos los registros con el mismo nombre de saps por el valor de su id correspondiente para que quede uno solo. Se reemplazará tanto el string como el nan, ya que ambos son valores de id para el mismo SAPS.

# %%
#obtengo los valores únicos de los nombres de los saps
saps=df_pato['SAPS'].unique()
#recorro cada valor
for nom in saps:
    #recupero el primer id del arreglo de ids
    if len(df_pato[df_pato['SAPS']==nom]['ID_SAPS'].unique())>0:
        id=df_pato[df_pato['SAPS']==nom]['ID_SAPS'].unique()[0]
    else:
        continue
    #ahora obtengo el índide de los registros con el nombre de saps que estamos analizando
    index_cambio=df_pato[df_pato['SAPS']==nom].index
    #si obtengo que para un determinado saps no hay índices, los evito por ahora
    if pd.isna(id) or id=="n/a":
        continue
     #con los índices anteriores, reemplazo por el id pertinente
    df_pato.iloc[index_cambio,0]=int(pd.to_numeric(id))

df_pato['ID_SAPS'].unique()
# Out:
# array([45, 47, 90, 76, 41, 88, nan, 49, 38, 48, 32, 75, 91, 58, 82, 42,
#        37, 36, 31, 54, 34, 86, 69, 62, 79, 46, 73, 85, 89, 71, 70, 51,
#        127, 99, 'n/a'], dtype=object)

# %%
df_pato[df_pato['SAPS']=='Dr. Saul Calmanash']['ID_SAPS'].unique()
# Out:
# array([45], dtype=object)

# %% [markdown]
# Tendremos algunos saps sin id establecidos. Veamos cuáles son

# %%
saps_sin_id=df_pato[(df_pato['ID_SAPS'].isnull()) | (df_pato['ID_SAPS']=="n/a")]['SAPS'].unique()
display(df_pato[(df_pato['ID_SAPS'].isnull()) | (df_pato['ID_SAPS']=="n/a")]['SAPS'].unique())
for saps in saps_sin_id:
    if pd.isna(saps) or saps=="n/a":
        continue
    print("SAPS: {}. IDS: {}".format(saps,df_pato[df_pato['SAPS']==saps]['ID_SAPS'].unique()))
# Out:
# array(['Dr. Anibal Malvido', 'Dr. Korimblum', 'Dr. Semper', 'Guemes',
#        'n/a'], dtype=object)
# SAPS: Dr. Anibal Malvido. IDS: [nan]
# SAPS: Dr. Korimblum. IDS: [nan]
# SAPS: Dr. Semper. IDS: [nan]
# SAPS: Guemes. IDS: [nan]

# %% [markdown]
# El resultado de arriba nos muestra que, si bien existen registros para el saps "Dr Anibal Malvido", no se le ha asignado ningún id. EL mismo criterio se aplica a los otros saps. Entonces, para que todos tengan un id, lo que hacemos es tomar el mayor id en el dataframe y, a partir de allí, darles id sucesivos a los saps que no tengan id establecido.

# %%
#filtro los datos para los casos en que no sean nulos y no tengan 'n/a' en el id
#obtengo el máximo y le sumo 1
nvo_id=df_pato[(df_pato['ID_SAPS'].notna()) & (df_pato['ID_SAPS']!='n/a')]['ID_SAPS'].max()+1
#obtengo los saps sin id
saps_sin_id=df_pato[(df_pato['ID_SAPS'].isnull()) | (df_pato['ID_SAPS']=="n/a")]['SAPS'].unique()
#recorro cada saps
for saps in saps_sin_id:
    #recupero los índices donde se presentan esos saps
    index_saps_sin_id=df_pato[df_pato['SAPS']==saps].index

    #en caso contrario, les asigno el id arbitrario y aumento el valor en 1
    df_pato.iloc[index_saps_sin_id,0]=nvo_id
    nvo_id+=1

# %%
#muestra que los saps anteriores si obtuvieron un nuevo id
for saps in saps_sin_id:
    if pd.isna(saps) or saps=="n/a":
        continue
    print("SAPS: {}. IDS: {}".format(saps,df_pato[df_pato['SAPS']==saps]['ID_SAPS'].unique()))
# Out:
# SAPS: Dr. Anibal Malvido. IDS: [128]
# SAPS: Dr. Korimblum. IDS: [129]
# SAPS: Dr. Semper. IDS: [130]
# SAPS: Guemes. IDS: [131]

# %%
#cambio los id a enteros
#df_pato['ID_SAPS']=df_pato['ID_SAPS'].astype(int)
index_noid_nosaps=df_pato[(df_pato['ID_SAPS'].isnull()) & (df_pato['SAPS'].isnull())].index
df_pato.iloc[index_noid_nosaps,0]=-1
df_pato.iloc[index_noid_nosaps,1]="n/a"
df_pato[df_pato['ID_SAPS'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID_SAPS, SAPS, fecha, patologia_desc, agrupacion_CIE10, patologia_cod, id_rango_etario, consulta_cantidad, rango_etario, sexo]
# Index: []

# %% [markdown]
# El último paso será darle los id permitentes al dataframe de saps para que queden igualados. El archivo con los datos de los saps no tiene el id para cada saps, así que le daremos el id que trae el conjunto de datos de las consultas por patología. De esa manera, se tendrá una homogeneidad para los id propios de cada saps.

# %%
#cargo los datos con la información de los saps(barrio, teléfono, etc)
df_saps=pd.read_csv(path_file("listado_saps.csv"))
#creo la nueva columna id_saps
df_saps.insert(0,"id_saps",[0 for i in np.arange(0,len(df_saps))])
#hago homogeneo los nombres de los saps
df_saps['saps']=df_saps['saps'].replace(dict_transformacion_saps)
nom_saps=df_pato['SAPS'].unique()
#recorro los nombres de los saps, analizando el dataframe con los datos de los saps
for saps in nom_saps:
    #si el saps que está en patologías figura en la lista de saps
    #obtengo el id del saps que está en la tabla de patologías
    #y se lo asigno al mismo saps en la lista de saps
    if len(df_saps[df_saps['saps']==saps])>0:
        id_saps=df_pato[df_pato['SAPS']==saps]['ID_SAPS'].unique()[0]
        df_saps.iloc[df_saps[df_saps['saps']==saps].index,0]=id_saps
        #print(id_saps)
    
df_saps
# Out:
#     id_saps                               saps                 barrio
# 0        76                 Dr. Romilio Monzón                Cichero  \
# 1       128                 Dr. Anibal Malvido                Pirayui
# 2        49               Dr. Benjamin Serrano         Parque Cadenas
# 3        31                   Dr. Elias Galvan                 Galvan
# 4        38              Dr. JC Benitez Suarez                  Lomas
# 5        47               Dr. Guillermo Rawson           San Geronimo
# 6        48        Dr. Jose de los Reyes Vidal             Santa Rita
# 7        51                  Dr. Juan Chercoff                 Yecoha
# 8       129                      Dr. Korimblum                    NaN
# 9        88                      Dr. Lifschitz            San Antonio
# 10       32                 Dr. Manuel Cassuso      San Antonio Oeste
# 11       41                Dr. Manuel Gonzalez      Lomas del Mirador
# 12       34                 Dr. Marcelino Vera         Caniada Quiroz
# 13       75                  Dr. Mauricio Open          San Francisco
# 14       82            Dr. Miguel Rossi Candia          Independencia
# 15       58                   Dr. Oscar Pirchi                  Anahi
# 16       91                Dr. Pedro Blugerman  Virgen de los dolores
# 17       42               Dr. Santiago Lorenzo           Barrio Nuevo
# 18       45                 Dr. Saul Calmanash                Quilmes
# 19      130                         Dr. Semper           Victor Colas
# 20       37                        Dr. Sussini           Barrio Ferre
# 21       36                          Esperanza              Esperanza
# 22      131                             Guemes              Guemes II
# 23       54                              Itati                  Itati
# 24       86                      Paso Martinez          Paso Martinez
# 25       69                      Primera Junta          Primera Junta
# 26       62                              Pujol                  Pujol
# 27       79                       Quinta Ferre           Quinta Ferre
# 28       46                         Rio Parana             Rio Parana
# 29       73                         San Marcos             San Marcos
# 30      127                     Santa Catalina         Santa Catalina
# 31       85                    Santa Margarita        Santa Margarita
# 32       89                        Santa Marta            Santa Marta
# 33       90                            Sapucay                Sapucay
# 34       71                     Villa Chiquita         Villa Chiquita
# 35       70                       Villa Garcia           Villa Garcia
# 36        0  Centro de distribucion de Vacunas                 Centro
# 37        0                              Samun           San Geronimo
#
#                                        ubicacion  contacto_telefono
# 0                   Guido Spano y Velez Sarfield         3794570325  \
# 1                       Suecia y Guillermo Ojeda         3794521654
# 2                                Ruta 5 km.2 1/2         3794293513
# 3                      Alverdi 2500 esq. Pizarro         3794815817
# 4   Mz. 1 Casa 1. Calles S. Mancini y Juan Pa.II         3794033767
# 5                           Centenario y Laprida         3794402928
# 6                              Perez ruedas 1989         3794783210
# 7          Ruta 12 - Km 1040. Ramona Galarza s/n         3794694771
# 8                           Guemes y Berazategui         3794595798
# 9          Horacio Quiroga esq. Roldan Belizario         3794765285
# 10                     Av. Alta Gracia y Atacama         3794093565
# 11                            Sicilia y calle 31         3794596347
# 12                                Caniada Quiroz         3794543910
# 13    Ruta 12-Km 1036 Acc. a Perichon-Aeropuerto         3794375939
# 14         Leloir 1900 entre Crespo y 2 de abril         3794601953
# 15                             Cristo Obrero 320         3794254379
# 16                       Monte de Oca y gutnisky         3794620527
# 17                     Ramos Mejia y Tupac Amaru         3794559274
# 18                                   Zarate 3400         3794759710
# 19                                   Argerich 40         3794604535
# 20                            3 de Abril y Chaco         3794827981
# 21                         114 Viv. Mz B, lote 8         3794403814
# 22             Gascon entre las Heras y Lamadrid         3794693558
# 23                         Amado Bompland al 100          379407688
# 24                                 Paso Martinez         3794776957
# 25       Nuestra Seniora de la Asuncion y Ex Via         3794244113
# 26                         Av.  Armenia y Yerbal         3794255159
# 27                          Zacarias Sanchez 400         3794386710
# 28                                  Mocoreta s/n         3794264648
# 29                               Roque Perez S/n         3794685366
# 30                         Montenegro y Dimotta          3794893212
# 31                                  Tacuaral s/n         3794753036
# 32                         Av. J.R. Vidal al sur         3794617051
# 33                        San Pio X. Ruta 5 km.4         3794401582
# 34                              Pirovano al 1998         3794241748
# 35                             Pasaje Paris 4098         3794065060
# 36             Salta y Placido Martinez (Puerto)         3794263779
# 37                          Centenario y Laprida         3794596656
#
#                    responsable            cargo
# 0                 Suarez Nancy         Director
# 1         Atoche Gennel Roland         Director
# 2                 Rezett Diego         Director
# 3         Lezcano Walter Ruben         Director
# 4                Romero Monica         Director
# 5                 Gomez Silvia         Director
# 6                Saucedo Mario         Director
# 7               Obregon Walter         Director
# 8              Blanchard Julio         Director
# 9               Mez Julio Jose         Director
# 10  Torres  Rodeles  A.  Sofia         Director
# 11          Gomez Baez Gustavo         Director
# 12      Solari Maria de los A.         Director
# 13           Rodriguez, Ramon          Director
# 14    Lic. Tabossi Silvia Edit         Director
# 15  Maria del Valle de Micheli         Director
# 16          Piragine Fernando          Director
# 17      Monzon, Maria Fernanda         Director
# 18      Mendieta Julia Beatriz         Director
# 19        D'andrea Juan Carlos         Director
# 20          Miranda Ramon Rito         Director
# 21      Solis Maria del Carmen         Director
# 22         Gomez Silvia Amalia         Director
# 23             Da Silva Desire         Director
# 24               Saucedo Jorge  Subsec. A Cargo
# 25      Avalos Maria de la Paz         Director
# 26                Tipeck Paola         Director
# 27           Contreras Eduardo         Director
# 28              Munioz Gustavo         Director
# 29  Rodriguez Belcastro Walter         Director
# 30           Gavilan Alejandro         Director
# 31                  Minio Abel         Director
# 32     Romero Maria del Carmen         Director
# 33             Insfran Gerardo         Director
# 34     Velarde Luis Guillermo          Director
# 35          Yfran Elba Beatriz         Director
# 36             Martinez Blanca              NaN
# 37          Eliaz atilio Ruben  Subsec. A Cargo

# %%
#puede darse el caso que haya saps en la lista de saps que no figuren en la lista
#de consultas por patologías. Por ejemplo, en el conjunto de datos de las consultas
#no figura que se haya hecho alguna consulta a ese saps.
#Entonces, le asignamos un id de la misma manera fue asignado antes.
#Ahora, se podrán tomar los id de los saps desde el archivo con los datos de los saps, pero esto es sólo una 
#solución transitoria. Si cada saps tiene un id específico, cuando se tenga ese dato, deberá realizarse el
#reemplazo pertinente
max_id_saps=df_saps['id_saps'].max()+1
for i in df_saps[df_saps['id_saps']==0].index:
    df_saps.iloc[i,0]=max_id_saps
    max_id_saps+=1

df_saps
# Out:
#     id_saps                               saps                 barrio
# 0        76                 Dr. Romilio Monzón                Cichero  \
# 1       128                 Dr. Anibal Malvido                Pirayui
# 2        49               Dr. Benjamin Serrano         Parque Cadenas
# 3        31                   Dr. Elias Galvan                 Galvan
# 4        38              Dr. JC Benitez Suarez                  Lomas
# 5        47               Dr. Guillermo Rawson           San Geronimo
# 6        48        Dr. Jose de los Reyes Vidal             Santa Rita
# 7        51                  Dr. Juan Chercoff                 Yecoha
# 8       129                      Dr. Korimblum                    NaN
# 9        88                      Dr. Lifschitz            San Antonio
# 10       32                 Dr. Manuel Cassuso      San Antonio Oeste
# 11       41                Dr. Manuel Gonzalez      Lomas del Mirador
# 12       34                 Dr. Marcelino Vera         Caniada Quiroz
# 13       75                  Dr. Mauricio Open          San Francisco
# 14       82            Dr. Miguel Rossi Candia          Independencia
# 15       58                   Dr. Oscar Pirchi                  Anahi
# 16       91                Dr. Pedro Blugerman  Virgen de los dolores
# 17       42               Dr. Santiago Lorenzo           Barrio Nuevo
# 18       45                 Dr. Saul Calmanash                Quilmes
# 19      130                         Dr. Semper           Victor Colas
# 20       37                        Dr. Sussini           Barrio Ferre
# 21       36                          Esperanza              Esperanza
# 22      131                             Guemes              Guemes II
# 23       54                              Itati                  Itati
# 24       86                      Paso Martinez          Paso Martinez
# 25       69                      Primera Junta          Primera Junta
# 26       62                              Pujol                  Pujol
# 27       79                       Quinta Ferre           Quinta Ferre
# 28       46                         Rio Parana             Rio Parana
# 29       73                         San Marcos             San Marcos
# 30      127                     Santa Catalina         Santa Catalina
# 31       85                    Santa Margarita        Santa Margarita
# 32       89                        Santa Marta            Santa Marta
# 33       90                            Sapucay                Sapucay
# 34       71                     Villa Chiquita         Villa Chiquita
# 35       70                       Villa Garcia           Villa Garcia
# 36      132  Centro de distribucion de Vacunas                 Centro
# 37      133                              Samun           San Geronimo
#
#                                        ubicacion  contacto_telefono
# 0                   Guido Spano y Velez Sarfield         3794570325  \
# 1                       Suecia y Guillermo Ojeda         3794521654
# 2                                Ruta 5 km.2 1/2         3794293513
# 3                      Alverdi 2500 esq. Pizarro         3794815817
# 4   Mz. 1 Casa 1. Calles S. Mancini y Juan Pa.II         3794033767
# 5                           Centenario y Laprida         3794402928
# 6                              Perez ruedas 1989         3794783210
# 7          Ruta 12 - Km 1040. Ramona Galarza s/n         3794694771
# 8                           Guemes y Berazategui         3794595798
# 9          Horacio Quiroga esq. Roldan Belizario         3794765285
# 10                     Av. Alta Gracia y Atacama         3794093565
# 11                            Sicilia y calle 31         3794596347
# 12                                Caniada Quiroz         3794543910
# 13    Ruta 12-Km 1036 Acc. a Perichon-Aeropuerto         3794375939
# 14         Leloir 1900 entre Crespo y 2 de abril         3794601953
# 15                             Cristo Obrero 320         3794254379
# 16                       Monte de Oca y gutnisky         3794620527
# 17                     Ramos Mejia y Tupac Amaru         3794559274
# 18                                   Zarate 3400         3794759710
# 19                                   Argerich 40         3794604535
# 20                            3 de Abril y Chaco         3794827981
# 21                         114 Viv. Mz B, lote 8         3794403814
# 22             Gascon entre las Heras y Lamadrid         3794693558
# 23                         Amado Bompland al 100          379407688
# 24                                 Paso Martinez         3794776957
# 25       Nuestra Seniora de la Asuncion y Ex Via         3794244113
# 26                         Av.  Armenia y Yerbal         3794255159
# 27                          Zacarias Sanchez 400         3794386710
# 28                                  Mocoreta s/n         3794264648
# 29                               Roque Perez S/n         3794685366
# 30                         Montenegro y Dimotta          3794893212
# 31                                  Tacuaral s/n         3794753036
# 32                         Av. J.R. Vidal al sur         3794617051
# 33                        San Pio X. Ruta 5 km.4         3794401582
# 34                              Pirovano al 1998         3794241748
# 35                             Pasaje Paris 4098         3794065060
# 36             Salta y Placido Martinez (Puerto)         3794263779
# 37                          Centenario y Laprida         3794596656
#
#                    responsable            cargo
# 0                 Suarez Nancy         Director
# 1         Atoche Gennel Roland         Director
# 2                 Rezett Diego         Director
# 3         Lezcano Walter Ruben         Director
# 4                Romero Monica         Director
# 5                 Gomez Silvia         Director
# 6                Saucedo Mario         Director
# 7               Obregon Walter         Director
# 8              Blanchard Julio         Director
# 9               Mez Julio Jose         Director
# 10  Torres  Rodeles  A.  Sofia         Director
# 11          Gomez Baez Gustavo         Director
# 12      Solari Maria de los A.         Director
# 13           Rodriguez, Ramon          Director
# 14    Lic. Tabossi Silvia Edit         Director
# 15  Maria del Valle de Micheli         Director
# 16          Piragine Fernando          Director
# 17      Monzon, Maria Fernanda         Director
# 18      Mendieta Julia Beatriz         Director
# 19        D'andrea Juan Carlos         Director
# 20          Miranda Ramon Rito         Director
# 21      Solis Maria del Carmen         Director
# 22         Gomez Silvia Amalia         Director
# 23             Da Silva Desire         Director
# 24               Saucedo Jorge  Subsec. A Cargo
# 25      Avalos Maria de la Paz         Director
# 26                Tipeck Paola         Director
# 27           Contreras Eduardo         Director
# 28              Munioz Gustavo         Director
# 29  Rodriguez Belcastro Walter         Director
# 30           Gavilan Alejandro         Director
# 31                  Minio Abel         Director
# 32     Romero Maria del Carmen         Director
# 33             Insfran Gerardo         Director
# 34     Velarde Luis Guillermo          Director
# 35          Yfran Elba Beatriz         Director
# 36             Martinez Blanca              NaN
# 37          Eliaz atilio Ruben  Subsec. A Cargo

# %% [markdown]
# # Trabajando Con La Tabla De Inmunizaciones

# %% [markdown]
# La tabla de datos de las inmunizaciones servirá posteriormente para crear una tabla de hechos y dimensiones propias, que compartirá algunas tablas de hechos con las consultas por patología.
# A continuación, se muestran los pasos para la limpieza de este conjunto de datos.

# %%
#cargo el dataframe
df_inmu=pd.read_csv(path_file("inmunizaciones.csv"))
df_inmu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27004 entries, 0 to 27003
# Data columns (total 26 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   ID_SAPS                                                              18862 non-null  object
#  1   SAPS                                                                 26003 non-null  object
#  2   fecha                                                                26003 non-null  object
#  3   mes                                                                  26999 non-null  object
#  4   año                                                                  26999 non-null  object
#  5   vacunas_tipo                                                         25984 non-null  object
#  6   vacunas_cantidad                                                     25983 non-null  object
#  7   Barrio del Operativo                                                 404 non-null    object
#  8   En caso de ser Operativo Territorial Indicar el Barrio en columna H  0 non-null      float64
#  9   Unnamed: 9                                                           1 non-null      object
#  10  Unnamed: 10                                                          0 non-null      float64
#  11  Unnamed: 11                                                          0 non-null      float64
#  12  Unnamed: 12                                                          0 non-null      float64
#  13  Unnamed: 13                                                          0 non-null      float64
#  14  Unnamed: 14                                                          0 non-null      float64
#  15  Unnamed: 15                                                          0 non-null      float64
#  16  Unnamed: 16                                                          0 non-null      float64
#  17  Unnamed: 17                                                          0 non-null      float64
#  18  Unnamed: 18                                                          0 non-null      float64
#  19  Unnamed: 19                                                          0 non-null      float64
#  20  Unnamed: 20                                                          0 non-null      float64
#  21  Unnamed: 21                                                          0 non-null      float64
#  22  Unnamed: 22                                                          0 non-null      float64
#  23  Unnamed: 23                                                          0 non-null      float64
#  24  Unnamed: 24                                                          0 non-null      float64
#  25  Unnamed: 25                                                          1 non-null      object
# dtypes: float64(16), object(10)
# memory usage: 5.4+ MB

# %% [markdown]
# Del resultado de arriba, notamos que tenemos muchos campos basura. Sólo nos quedaremos con los campos:  ID_SAPS, SAPS, fecha, vacunas_tipo,vacunas_cantidad.

# %%
#obtenemos sólo las columnas que queremos analizar
df_inmu=df_inmu[['ID_SAPS','SAPS','fecha','vacunas_tipo','vacunas_cantidad']]
df_inmu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27004 entries, 0 to 27003
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_SAPS           18862 non-null  object
#  1   SAPS              26003 non-null  object
#  2   fecha             26003 non-null  object
#  3   vacunas_tipo      25984 non-null  object
#  4   vacunas_cantidad  25983 non-null  object
# dtypes: object(5)
# memory usage: 1.0+ MB

# %%
df_inmu[(df_inmu['vacunas_tipo'].isna()) & (df_inmu['vacunas_cantidad'].notna())]
# Out:
#       ID_SAPS           SAPS       fecha vacunas_tipo vacunas_cantidad
# 19405     NaN  DR. KORIMBLUM  01/08/2023          NaN                3
# 20440      37    DR. SUSSINI  01/11/2023          NaN               23

# %% [markdown]
# Podemos notar que hay saps sin id. Veamos cuáles son los id para el archivo de inmunizaciones y para el archivo con los datos de los saps.

# %%
df_inmu.sort_values(by="fecha",ascending=False)
# Out:
#       ID_SAPS                   SAPS       fecha              vacunas_tipo
# 17321      49   DR. BENJAMIN SERRANO  30/12/1899                       HPV  \
# 19288      88  DR. ALBERTO LIFSCHITZ  30/12/1899  NEUMOCOCICA NO CONJUGADA
# 3082       90                SAPUCAY  2020-07-01          DOBLE BACTERIANA
# 3099      NaN             DR. SEMPER  2020-07-01                       HPV
# 3108       37            DR. SUSSINI  2020-07-01               HEPATITIS A
# ...       ...                    ...         ...                       ...
# 26999     NaN                    NaN         NaN                       NaN
# 27000     NaN                    NaN         NaN                       NaN
# 27001     NaN                    NaN         NaN                       NaN
# 27002     NaN                    NaN         NaN                       NaN
# 27003     NaN                    NaN         NaN                       NaN
#
#       vacunas_cantidad
# 17321               18
# 19288                6
# 3082                 7
# 3099                 3
# 3108                12
# ...                ...
# 26999              NaN
# 27000              NaN
# 27001              NaN
# 27002              NaN
# 27003              NaN
#
# [27004 rows x 5 columns]

# %%
df_inmu[(df_inmu['ID_SAPS'].notnull() & (df_inmu['SAPS'].isnull()))]
# Out:
# Empty DataFrame
# Columns: [ID_SAPS, SAPS, fecha, vacunas_tipo, vacunas_cantidad]
# Index: []

# %%
#transformamos en un conjunto los ids únicos de los saps
set_id_saps=set(df_saps['id_saps'].unique())
#hacemos lo mismo para las inmunizaciones, sólo que los nan y #REF! se
#reemplazan por -1
set_id_inmu=set(df_inmu['ID_SAPS'].fillna(-1).replace({'#REF!':-1}).astype(int).unique())
#aplicamos la diferencia entre ambos conjuntos
print("Los id que están en inmunizaciones y no en los saps: {}".format(set_id_inmu.difference(set_id_saps)))
#print(set_id_inmu)
df_inmu.info()
# Out:
# Los id que están en inmunizaciones y no en los saps: {99, -1}
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27004 entries, 0 to 27003
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_SAPS           18862 non-null  object
#  1   SAPS              26003 non-null  object
#  2   fecha             26003 non-null  object
#  3   vacunas_tipo      25984 non-null  object
#  4   vacunas_cantidad  25983 non-null  object
# dtypes: object(5)
# memory usage: 1.0+ MB

# %% [markdown]
# El resultado anterior nos muestra esos tres id que figuran en el archivo de inmunizaciones, pero no en el archivo de saps. El -1 hace referencia a campos que no tienen id asignado. Observemos primero para los id 99.

# %%
display(df_inmu[df_inmu['ID_SAPS']=='99'].head(1))
# Out:
#      ID_SAPS                      SAPS       fecha vacunas_tipo
# 3434      99  OPERATIVOS TERRITORIALES  01-07-2020  HEPATITIS B  \
#
#      vacunas_cantidad
# 3434                1

# %% [markdown]
# El -1 indica que no hay datos del id. Esto es así porque aun no he transformado los nombres de los saps en el dataframe de las inmunizaciones para que se igualen a los que figuran en las consultas por patología y los saps. Voy a realizar esa transformación y ver cómo se modifican los id que están presentes en las inmunizaciones y que no están presentes en los saps.

# %%
#quitamos los espacios en blanco
df_inmu['SAPS']=df_inmu['SAPS'].str.strip()
#transformo los nombres para igualarlos con los del saps.
df_inmu['SAPS']=df_inmu['SAPS'].replace(dict_transformacion_saps)
#tranformamos los nombres de los saps para que sea igual a los nombres de los otros
#recorro todos los saps
for saps in df_saps['saps'].unique():
    #si el saps figura en la tabla de inmunizaciones
    if len(df_inmu[df_inmu['SAPS']==saps])>0:
        df_inmu.iloc[df_inmu[df_inmu['SAPS']==saps].index,0]=df_saps[df_saps['saps']==saps]['id_saps'].unique()[0]

df_inmu[df_inmu['ID_SAPS'].isnull()]['SAPS'].unique()
# Out:
# array([nan], dtype=object)

# %%
#transformamos en un conjunto los ids únicos de los saps
set_id_saps=set(df_saps['id_saps'].unique())
#hacemos lo mismo para las inmunizaciones, sólo que los nan y #REF! se
#reemplazan por -1
set_id_inmu=set(df_inmu['ID_SAPS'].fillna(-1).replace({'#REF!':-1}).astype(int).unique())
#aplicamos la diferencia entre ambos conjuntos
print("Los id que están en inmunizaciones y no en los saps: {}".format(set_id_inmu.difference(set_id_saps)))
#print(set_id_inmu)
# Out:
# Los id que están en inmunizaciones y no en los saps: {99, -1}

# %% [markdown]
# Todavía tenemos -1. Es decir, que hay id con saps en nulos ambos o tenemos saps en inmunizaciones cuyos nombres no figuran en la lista de saps.

# %%
df_inmu[(df_inmu['ID_SAPS'].isnull()) & (df_inmu['SAPS'].notnull())]
# Out:
# Empty DataFrame
# Columns: [ID_SAPS, SAPS, fecha, vacunas_tipo, vacunas_cantidad]
# Index: []

# %% [markdown]
# El resultado de arriba, nos dice que no tenemos nombres de saps sin nulos y que, a la vez, tengamos id_saps nulos.

# %%
df_inmu[(df_inmu['ID_SAPS'].isnull()) & (df_inmu['SAPS'].isnull())].head()
# Out:
#       ID_SAPS SAPS fecha vacunas_tipo vacunas_cantidad
# 26003     NaN  NaN   NaN          NaN              NaN
# 26004     NaN  NaN   NaN          NaN              NaN
# 26005     NaN  NaN   NaN          NaN              NaN
# 26006     NaN  NaN   NaN          NaN              NaN
# 26007     NaN  NaN   NaN          NaN              NaN

# %% [markdown]
# Ahora vemos que sí hay datos sin id_saps ni nombre de saps. Además, vemos que tenemos datos con los 5 campos sin datos. Estos registros no son útiles para nada. Una solución sería buscar los índices que cumplan esta condición y eliminarlos.

# %%
#elimina las filas donde todas sus columnas tengan valores nulos
df_inmu= df_inmu.dropna(how="all")

# %%
#revisamos una vez más, y notamos que ya no hay casos donde ambos: nombre e id de saps, 
#sean nulos a la vez.
df_inmu[(df_inmu['ID_SAPS'].isnull()) & (df_inmu['SAPS'].isnull())].head()
# Out:
# Empty DataFrame
# Columns: [ID_SAPS, SAPS, fecha, vacunas_tipo, vacunas_cantidad]
# Index: []

# %% [markdown]
# Revisemos algunos casos más:
# 1. Donde tenemos valores para las vacunas aplicadas, pero no sabemos su tipo.
# 2. Donde tenemos el tipo de vacuna, pero no su cantidad aplicada.
# 3. Donde tenemos cantidad de vacunas aplicadas, pero no tenemos sus saps.
# 4. Donde tenemos tipo de vacunas aplicadas, pero no tenemos su saps.
# 5. Donde no tengamos ni tipo de vacunas ni cantidad de vacunas.

# %%
#1.revisamos donde tenemos las cantidades, pero no los tipos de vacunas
df_inmu[(df_inmu['vacunas_cantidad'].notnull()) & (df_inmu['vacunas_tipo'].isnull())]
# Out:
#       ID_SAPS           SAPS       fecha vacunas_tipo vacunas_cantidad
# 19405     129  Dr. Korimblum  01/08/2023          NaN                3
# 20440      37    Dr. Sussini  01/11/2023          NaN               23

# %%
#2.revisamos los casos donde tenemos los tipos de vacunas, pero no las cantidades.
df_inmu[(df_inmu['vacunas_cantidad'].isnull()) & (df_inmu['vacunas_tipo'].notnull())]
# Out:
#      ID_SAPS                     SAPS       fecha  vacunas_tipo
# 24        47     Dr. Guillermo Rawson  2020-01-01    SABIN ORAL  \
# 8443      99  OPERATIVO TERRITORIALES  01/06/2021  PENTAVALENTE
# 8469      82  Dr. Miguel Rossi Candia  01/07/2021   HEPATITIS B
#
#      vacunas_cantidad
# 24                NaN
# 8443              NaN
# 8469              NaN

# %%
#3.Donde tenemos la cantidad de vacunas, pero no los saps
df_inmu[(df_inmu['vacunas_cantidad'].notnull()) & (df_inmu['SAPS'].isnull())]
# Out:
# Empty DataFrame
# Columns: [ID_SAPS, SAPS, fecha, vacunas_tipo, vacunas_cantidad]
# Index: []

# %%
#4.Donde tenemos los tipos de vacunas, pero no los saps
df_inmu[(df_inmu['vacunas_tipo'].notnull()) & (df_inmu['vacunas_tipo'].isnull())]
# Out:
# Empty DataFrame
# Columns: [ID_SAPS, SAPS, fecha, vacunas_tipo, vacunas_cantidad]
# Index: []

# %%
#5.Donde no tengamos ni tipo de vacunas ni cantidad de vacunas.
df_inmu[(df_inmu['vacunas_tipo'].isnull()) & (df_inmu['vacunas_tipo'].isnull())].sort_values("fecha",ascending=True)
# Out:
#       ID_SAPS                         SAPS       fecha vacunas_tipo
# 2389       47         Dr. Guillermo Rawson  01-06-2020          NaN  \
# 17422      48  Dr. Jose de los Reyes Vidal  01/04/2023          NaN
# 19405     129                Dr. Korimblum  01/08/2023          NaN
# 19900      76           Dr. Romilio Monzón  01/10/2023          NaN
# 20440      37                  Dr. Sussini  01/11/2023          NaN
# 18         45           Dr. Saul Calmanash  2020-01-01          NaN
# 16         45           Dr. Saul Calmanash  2020-01-01          NaN
# 15         45           Dr. Saul Calmanash  2020-01-01          NaN
# 11         45           Dr. Saul Calmanash  2020-01-01          NaN
# 0          45           Dr. Saul Calmanash  2020-01-01          NaN
# 7          45           Dr. Saul Calmanash  2020-01-01          NaN
# 6          45           Dr. Saul Calmanash  2020-01-01          NaN
# 5          45           Dr. Saul Calmanash  2020-01-01          NaN
# 4          45           Dr. Saul Calmanash  2020-01-01          NaN
# 3          45           Dr. Saul Calmanash  2020-01-01          NaN
# 2          45           Dr. Saul Calmanash  2020-01-01          NaN
# 1          45           Dr. Saul Calmanash  2020-01-01          NaN
# 9          45           Dr. Saul Calmanash  2020-01-01          NaN
# 10         45           Dr. Saul Calmanash  2020-01-01          NaN
#
#       vacunas_cantidad
# 2389               NaN
# 17422              NaN
# 19405                3
# 19900              NaN
# 20440               23
# 18                 NaN
# 16                 NaN
# 15                 NaN
# 11                 NaN
# 0                  NaN
# 7                  NaN
# 6                  NaN
# 5                  NaN
# 4                  NaN
# 3                  NaN
# 2                  NaN
# 1                  NaN
# 9                  NaN
# 10                 NaN

# %% [markdown]
# De lo analizado anteriormente, vemos que se cumplen sólo los casos 1, 2 y 5. Podemos colocar los tipos de vacunas al valor "n/a" y las cantidades a -1 para indicar la ausencia de datos

# %%
#indices para los registros con cantidad de vacunas aplicadas, pero sin el tipo
indice_cantidad_sin_tipo=df_inmu[(df_inmu['vacunas_cantidad'].notnull()) & (df_inmu['vacunas_tipo'].isnull())].index
#el 3 indica que es la columna de índice 3 la que indica el tipo de vacuna
df_inmu.iloc[indice_cantidad_sin_tipo,3]="n/a"
df_inmu[(df_inmu['vacunas_cantidad'].notnull()) & (df_inmu['vacunas_tipo']=="n/a")]
# Out:
#       ID_SAPS           SAPS       fecha vacunas_tipo vacunas_cantidad
# 19405     129  Dr. Korimblum  01/08/2023          n/a                3
# 20440      37    Dr. Sussini  01/11/2023          n/a               23

# %%
#indices para los registros con cantidad de vacunas aplicadas, pero sin el tipo
indice_tipo_sin_cantidad=df_inmu[(df_inmu['vacunas_cantidad'].isnull()) & (df_inmu['vacunas_tipo'].notnull())].index
#el 4 indica que es la columna de índice 4, la cual representa la cantidad de vacunas
df_inmu.iloc[indice_tipo_sin_cantidad,4]=-1
df_inmu[(df_inmu['vacunas_cantidad']==-1) & (df_inmu['vacunas_tipo'].notnull())]
# Out:
#      ID_SAPS                     SAPS       fecha  vacunas_tipo
# 24        47     Dr. Guillermo Rawson  2020-01-01    SABIN ORAL  \
# 8443      99  OPERATIVO TERRITORIALES  01/06/2021  PENTAVALENTE
# 8469      82  Dr. Miguel Rossi Candia  01/07/2021   HEPATITIS B
#
#      vacunas_cantidad
# 24                 -1
# 8443               -1
# 8469               -1

# %% [markdown]
# Analicemos en quinto escenario

# %%
df_inmu[(df_inmu['vacunas_cantidad'].isnull()) & (df_inmu['vacunas_tipo'].isnull())]
# Out:
#       ID_SAPS                         SAPS       fecha vacunas_tipo
# 0          45           Dr. Saul Calmanash  2020-01-01          NaN  \
# 1          45           Dr. Saul Calmanash  2020-01-01          NaN
# 2          45           Dr. Saul Calmanash  2020-01-01          NaN
# 3          45           Dr. Saul Calmanash  2020-01-01          NaN
# 4          45           Dr. Saul Calmanash  2020-01-01          NaN
# 5          45           Dr. Saul Calmanash  2020-01-01          NaN
# 6          45           Dr. Saul Calmanash  2020-01-01          NaN
# 7          45           Dr. Saul Calmanash  2020-01-01          NaN
# 9          45           Dr. Saul Calmanash  2020-01-01          NaN
# 10         45           Dr. Saul Calmanash  2020-01-01          NaN
# 11         45           Dr. Saul Calmanash  2020-01-01          NaN
# 15         45           Dr. Saul Calmanash  2020-01-01          NaN
# 16         45           Dr. Saul Calmanash  2020-01-01          NaN
# 18         45           Dr. Saul Calmanash  2020-01-01          NaN
# 2389       47         Dr. Guillermo Rawson  01-06-2020          NaN
# 17422      48  Dr. Jose de los Reyes Vidal  01/04/2023          NaN
# 19900      76           Dr. Romilio Monzón  01/10/2023          NaN
#
#       vacunas_cantidad
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 15                 NaN
# 16                 NaN
# 18                 NaN
# 2389               NaN
# 17422              NaN
# 19900              NaN

# %% [markdown]
# Esto podríamos interpretarlo de dos maneras:
# 1. Amputamos los datos porque al no tener información sustancial, no serían útiles.
# 2. Los mantenemos porque a pesar de no tener el tipo ni la cantidad, nos dice que en esos días sí se aplicaron vacunas, aunque no sabemos cuántas y cuáles.
#
# Por lo pronto, vamos a seguir con la misma idea: "n/a" para los tipos de vacunas, -1 para la cantidades, si es que se tienen datos NaN

# %%
index_ni_cantidad_ni_tipo=df_inmu[(df_inmu['vacunas_cantidad'].isnull()) & (df_inmu['vacunas_tipo'].isnull())].index
df_inmu.iloc[index_ni_cantidad_ni_tipo,3]='n/a'
df_inmu.iloc[index_ni_cantidad_ni_tipo,4]=-1
df_inmu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26003 entries, 0 to 26002
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_SAPS           26003 non-null  object
#  1   SAPS              26003 non-null  object
#  2   fecha             26003 non-null  object
#  3   vacunas_tipo      26003 non-null  object
#  4   vacunas_cantidad  26003 non-null  object
# dtypes: object(5)
# memory usage: 1.2+ MB

# %% [markdown]
# Y vemos que, finalmente, nos quedamos sin NaN en ninguna columna. Sólo falta darle a la fecha el formato pertinente, convertir los id en enteros al igual que las cantidades.
# Un paso importante que no se hizo es revisar los valores que tiene el campo de cantidades de vacunas adminsitradas.

# %%
df_inmu['vacunas_cantidad'].unique()
# Out:
# array([-1, '1', '10', '5', '14', '4', '11', '30', '6', '3', '8', '32',
#        '2', '7', '17', '12', '37', '31', '9', '33', '28', '22', '13',
#        '15', '18', '16', '20', '39', '21', '23', '19', '60', '26', '51',
#        '34', '40', '24', '29', '41', '25', '27', '53', '54', '62', '49',
#        '35', '77', '158', '160', '110', '143', '149', '115', '50', '175',
#        '157', '167', '118', '86', '63', '220', '215', '122', '109', '98',
#        '69', '44', '45', '46', '43', '38', '95', '181', '196', '93',
#        '165', '96', '176', '244', '67', '294', '70', '188', '64', '97',
#        '349', '130', '178', '325', '104', '113', '144', '198', '108',
#        '170', '298', '133', '258', '58', '36', '172', '120', '100', '163',
#        '125', '66', '90', '156', '474', '131', '74', '65', '189', '48',
#        '52', '56', '59', '55', '0', '225', '134', '71', '89', '83', '73',
#        '42', '111', '123', '94', '47', '68', '150', '177', '132', '185',
#        '72', '137', '161', '127', '107', '182', '84', '162', '102', '61',
#        '-', '85', '75', '87', '57', '80', '76', '155', '314', '79', '142',
#        '186', '101', '119', '312', '´1'], dtype=object)

# %% [markdown]
# Puede notarse que hay un valor '-' y '´1' que no son numéricos. Así que vamos a cambiarlo a -1 también para evitar problemas.

# %%
df_inmu.iloc[df_inmu[df_inmu['vacunas_cantidad']=='-'].index,4]=-1
df_inmu.iloc[df_inmu[df_inmu['vacunas_cantidad']=='´1'].index,4]=1

# %% [markdown]
# Ahora sí, cambiemos los tipos de datos.

# %%
df_inmu['fecha']=df_inmu['fecha'].replace("/","-").astype(str)
df_inmu['fecha']=df_inmu['fecha'].apply(normalizar_fecha)
df_inmu['fecha']=pd.to_datetime(df_inmu['fecha'])
df_inmu['ID_SAPS']=df_inmu['ID_SAPS'].astype(int)
df_inmu['vacunas_cantidad']=df_inmu['vacunas_cantidad'].astype(int)
df_inmu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26003 entries, 0 to 26002
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID_SAPS           26003 non-null  int32
#  1   SAPS              26003 non-null  object
#  2   fecha             26003 non-null  datetime64[ns]
#  3   vacunas_tipo      26003 non-null  object
#  4   vacunas_cantidad  26003 non-null  int32
# dtypes: datetime64[ns](1), int32(2), object(2)
# memory usage: 1015.7+ KB

# %% [markdown]
# Revisemos algunos datos más, como los valores en los tipos de vacunas.

# %%
df_inmu['vacunas_tipo']=df_inmu['vacunas_tipo'].str.strip()
df_inmu['vacunas_tipo'].unique()
# Out:
# array(['n/a', 'ANTI GRIPAL', 'FIEBRE AMARILLA', 'DPT', 'DPT (a)', 'HPV',
#        'HEPATITIS B', 'SALK', 'ROTAVIRUS', 'PENTAVALENTE',
#        'NEUMOCOCICA CONJUGADA', 'SABIN ORAL', 'TRIPLE VIRAL',
#        'HEPATITIS A', 'VARICELA', 'DOBLE BACTERIANA', 'MENINGOCOC.',
#        'NEUMOCOCICA NO CONJUGADA', 'DOBLE VIRAL', 'MENVEO', 'BCG',
#        'MENACTRA', 'TRIPLE BACTERIANA', 'NEUMO13', 'NEUMO 23', 'DTA',
#        'GRIPE A', 'OTRAS', 'DOBLE ADULTO', 'NEUMO23', 'ANTIGRIPAL ADULTO',
#        'ANTIGRIPAL PEDIATRICO', 'NEUMO 13', 'ANT. PEDIAT.',
#        'ANTIGRIPAL PEDIA.', 'ANTI GRIPAL ADULTO', 'GRIPE', 'GRIPR A',
#        'DT', 'DTO', 'ANTI AMARILLICA', 'ANTI GRIPAL PEDIATRICO',
#        'BEXSERRO', 'PEDIAT', 'FLUXVIR', 'BEXSERO', 'O. SABIN', 'FLUXVIRG',
#        'PREV 13', 'ANTIGRIPAL PEDITRICO', 'MENANTRA',
#        'ANTIGRIPAL MAYORES', 'H', 'SA', 'OTROS', 'GRIPE +65',
#        'PREVENAR 13', 'MAYOR 65', 'ANTIPEDIATRICO', 'ANT. PEDIAYTICO',
#        'B', 'CAMPAÑA/22', 'GRIPAL', 'FLUVIA', 'A. CELULA', 'VSR',
#        'SINCISIAL', 'HP'], dtype=object)

# %% [markdown]
# Vemos que existen algunos que podrían ser iguales, pero con errores como nombres, espacios, etc:
# - NEUMO13, NEUMO 13
# - NUEMO23, NEUMO 23
# - ANTIGRIPAL PEDIATRICO, ANTI GRIPAL PEDIATRICO, ANT. PEDIAYTICO
# Podemos preparar los resultados con un diccionario para igualar los resultados. Además, podemos eliminar los espacios en blanco presentes.

# %%
#creo un diccionario donde cada vacuna será su clave y su valor
dict_vacunas = {v: v for v in df_inmu['vacunas_tipo'].unique()}

dict_vacunas
# Out:
# {'n/a': 'n/a',
#  'ANTI GRIPAL': 'ANTI GRIPAL',
#  'FIEBRE AMARILLA': 'FIEBRE AMARILLA',
#  'DPT': 'DPT',
#  'DPT (a)': 'DPT (a)',
#  'HPV': 'HPV',
#  'HEPATITIS B': 'HEPATITIS B',
#  'SALK': 'SALK',
#  'ROTAVIRUS': 'ROTAVIRUS',
#  'PENTAVALENTE': 'PENTAVALENTE',
#  'NEUMOCOCICA CONJUGADA': 'NEUMOCOCICA CONJUGADA',
#  'SABIN ORAL': 'SABIN ORAL',
#  'TRIPLE VIRAL': 'TRIPLE VIRAL',
#  'HEPATITIS A': 'HEPATITIS A',
#  'VARICELA': 'VARICELA',
#  'DOBLE BACTERIANA': 'DOBLE BACTERIANA',
#  'MENINGOCOC.': 'MENINGOCOC.',
#  'NEUMOCOCICA NO CONJUGADA': 'NEUMOCOCICA NO CONJUGADA',
#  'DOBLE VIRAL': 'DOBLE VIRAL',
#  'MENVEO': 'MENVEO',
#  'BCG': 'BCG',
#  'MENACTRA': 'MENACTRA',
#  'TRIPLE BACTERIANA': 'TRIPLE BACTERIANA',
#  'NEUMO13': 'NEUMO13',
#  'NEUMO 23': 'NEUMO 23',
#  'DTA': 'DTA',
#  'GRIPE A': 'GRIPE A',
#  'OTRAS': 'OTRAS',
#  'DOBLE ADULTO': 'DOBLE ADULTO',
#  'NEUMO23': 'NEUMO23',
#  'ANTIGRIPAL ADULTO': 'ANTIGRIPAL ADULTO',
#  'ANTIGRIPAL PEDIATRICO': 'ANTIGRIPAL PEDIATRICO',
#  'NEUMO 13': 'NEUMO 13',
#  'ANT. PEDIAT.': 'ANT. PEDIAT.',
#  'ANTIGRIPAL PEDIA.': 'ANTIGRIPAL PEDIA.',
#  'ANTI GRIPAL ADULTO': 'ANTI GRIPAL ADULTO',
#  'GRIPE': 'GRIPE',
#  'GRIPR A': 'GRIPR A',
#  'DT': 'DT',
#  'DTO': 'DTO',
#  'ANTI AMARILLICA': 'ANTI AMARILLICA',
#  'ANTI GRIPAL PEDIATRICO': 'ANTI GRIPAL PEDIATRICO',
#  'BEXSERRO': 'BEXSERRO',
#  'PEDIAT': 'PEDIAT',
#  'FLUXVIR': 'FLUXVIR',
#  'BEXSERO': 'BEXSERO',
#  'O. SABIN': 'O. SABIN',
#  'FLUXVIRG': 'FLUXVIRG',
#  'PREV 13': 'PREV 13',
#  'ANTIGRIPAL PEDITRICO': 'ANTIGRIPAL PEDITRICO',
#  'MENANTRA': 'MENANTRA',
#  'ANTIGRIPAL MAYORES': 'ANTIGRIPAL MAYORES',
#  'H': 'H',
#  'SA': 'SA',
#  'OTROS': 'OTROS',
#  'GRIPE +65': 'GRIPE +65',
#  'PREVENAR 13': 'PREVENAR 13',
#  'MAYOR 65': 'MAYOR 65',
#  'ANTIPEDIATRICO': 'ANTIPEDIATRICO',
#  'ANT. PEDIAYTICO': 'ANT. PEDIAYTICO',
#  'B': 'B',
#  'CAMPAÑA/22': 'CAMPAÑA/22',
#  'GRIPAL': 'GRIPAL',
#  'FLUVIA': 'FLUVIA',
#  'A. CELULA': 'A. CELULA',
#  'VSR': 'VSR',
#  'SINCISIAL': 'SINCISIAL',
#  'HP': 'HP'}

# %% [markdown]
# Con los datos generados arriba, busco cuáles se repiten por errores de tipeo y, arreglando el diccionario, posteriormente lo usaré para homogeneizar los nombres de las vacunas.

# %%
#los errores en el diccionario por errores de tipeo, los arreglo
#{'ANTIGRIPAL PEDIA.':'ANTIGRIPAL PEDIA.'}
#{'ANTIGRIPAL PEDIA.':'ANTIGRIPAL PEDIATRICO'}
dict_vacunas['ANTIGRIPAL PEDIA.']='ANTIGRIPAL PEDIATRICO'
dict_vacunas['ANTI GRIPAL PEDIATRICO']='ANTIGRIPAL PEDIATRICO'
dict_vacunas['ANTIGRIPAL PEDITRICO']='ANTIGRIPAL PEDIATRICO'
dict_vacunas['ANT. PEDIAYTICO']='ANTIGRIPAL PEDIATRICO'
dict_vacunas['ANTIPEDIATRICO']='ANTIGRIPAL PEDIATRICO'
dict_vacunas['ANT. PEDIAT.']='ANTIGRIPAL PEDIATRICO'
dict_vacunas['ANTI GRIPAL ADULTO']='ANTIGRIPAL ADULTO'
dict_vacunas['GRIPR A']='GRIPE A'
dict_vacunas['ANTI AMARILLICA']='FIEBRE AMARILLA'
#dict_vacunas['ANTI AMARILLICA']='FIEBRE AMARILLA'

df_inmu['vacunas_tipo']=df_inmu['vacunas_tipo'].map(dict_vacunas)
df_inmu['vacunas_tipo'].unique()
# Out:
# array(['n/a', 'ANTI GRIPAL', 'FIEBRE AMARILLA', 'DPT', 'DPT (a)', 'HPV',
#        'HEPATITIS B', 'SALK', 'ROTAVIRUS', 'PENTAVALENTE',
#        'NEUMOCOCICA CONJUGADA', 'SABIN ORAL', 'TRIPLE VIRAL',
#        'HEPATITIS A', 'VARICELA', 'DOBLE BACTERIANA', 'MENINGOCOC.',
#        'NEUMOCOCICA NO CONJUGADA', 'DOBLE VIRAL', 'MENVEO', 'BCG',
#        'MENACTRA', 'TRIPLE BACTERIANA', 'NEUMO13', 'NEUMO 23', 'DTA',
#        'GRIPE A', 'OTRAS', 'DOBLE ADULTO', 'NEUMO23', 'ANTIGRIPAL ADULTO',
#        'ANTIGRIPAL PEDIATRICO', 'NEUMO 13', 'GRIPE', 'DT', 'DTO',
#        'BEXSERRO', 'PEDIAT', 'FLUXVIR', 'BEXSERO', 'O. SABIN', 'FLUXVIRG',
#        'PREV 13', 'MENANTRA', 'ANTIGRIPAL MAYORES', 'H', 'SA', 'OTROS',
#        'GRIPE +65', 'PREVENAR 13', 'MAYOR 65', 'B', 'CAMPAÑA/22',
#        'GRIPAL', 'FLUVIA', 'A. CELULA', 'VSR', 'SINCISIAL', 'HP'],
#       dtype=object)

# %%
rows = []
for pat in df_pato['patologia_cod'].unique():
    for desc in df_pato.loc[df_pato['patologia_cod'] == pat, 'patologia_desc'].unique():
        rows.append({
            'patologia_cod': pat,
            'patologia_desc': desc
        })

df_cie_desc = pd.DataFrame(rows)
df_cie_desc
# Out:
#      patologia_cod                                     patologia_desc
# 0             Z001           CONTROL DEL NIÑO SANO - CONTROL DE SALUD
# 1              A09  DIARREA Y GASTROENTERITIS DE PRESUNTO ORIGEN I...
# 2              I10                   HIPERTENSION ESENCIAL (PRIMARIA)
# 3              I10                  ANEMIAS POR DEFICIENCIA DE HIERRO
# 4              I10           DIABETES MELLITUS NO INSULINODEPENDIENTE
# ...            ...                                                ...
# 1000           B19           HEPÀTITIS VIRAL, SIN OTRA ESPECIFICACION
# 1001           O08  COMPLICACIONES CONSECUTIVAS AL ABORTO, AL EMBA...
# 1002           J94                      OTRAS AFECCIONES DE LA PLEURA
# 1003          R196                                          HALITOSIS
# 1004          U207                      INFECCION DEL CUERO CABELLUDO
#
# [1005 rows x 2 columns]

# %%
df_cie_desc = (
    df_pato[['patologia_cod', 'patologia_desc']]
    .dropna()
    .drop_duplicates()
    .reset_index(drop=True)
)

df_cie_desc
# Out:
#      patologia_cod                                     patologia_desc
# 0             Z001           CONTROL DEL NIÑO SANO - CONTROL DE SALUD
# 1              A09  DIARREA Y GASTROENTERITIS DE PRESUNTO ORIGEN I...
# 2              I10                   HIPERTENSION ESENCIAL (PRIMARIA)
# 3              E10              DIABETES MELLITUS INSULINODEPENDIENTE
# 4              N23                      COLICO RENAL, NO ESPECIFICADO
# ...            ...                                                ...
# 1000           B19           HEPÀTITIS VIRAL, SIN OTRA ESPECIFICACION
# 1001           O08  COMPLICACIONES CONSECUTIVAS AL ABORTO, AL EMBA...
# 1002           J94                      OTRAS AFECCIONES DE LA PLEURA
# 1003          R196                                          HALITOSIS
# 1004          U207                      INFECCION DEL CUERO CABELLUDO
#
# [1005 rows x 2 columns]

# %% [markdown]
# # Algunas consultas que podemos realizar

# %% [markdown]
# 1. Crear una columna con los meses por año, agrupar las consultas por esa nueva columna, y obtener el total de consultas.

# %%
#obtengo el año y mes de cada fecha
#df_pato['y-m']=df_pato['fecha'].dt.to_period('M')
#df_pato['y-m'].head()

# %%
#agrupo los registros por los valores de la columna 'y-m' y aplico la agregación
#de suma. Reseteo los índices para que quede un nuevo dataframe
#df_pato.groupby('y-m')['consulta_cantidad'].sum().reset_index().head()

# %% [markdown]
# 2. Cómo sumar meses, días o años a nuestras fechas

# %%
#suma 2 meses y 5 días a cada fecha
#El formato básico es: variable_fecha + pd.DateOffset(year=anios, months=meses, days=días)
#df_pato['fecha'] + pd.DateOffset(months=2,days=5)

# %% [markdown]
# 3. Algunos filtros para las fechas

# %%
#filtrar las fechas sólo por el año y el mes
#df_pato[df_pato['fecha'].dt.strftime('%Y-%m')=='2020-06'].head()

# %%
#filtramos teniendo en cuenta sólo el mes
#df_pato[df_pato['fecha'].dt.month==6].tail()

# %% [markdown]
# # Control De Duplicados

# %%
#control de duplicados
#display(df_inmu.iloc[df_inmu.duplicated().index])
print("Total Duplicados para las patologias: {}".format(df_pato.duplicated().sum()))
print("Total Duplicados para los saps: {}".format(df_saps.duplicated().sum()))
print("Total Duplicados para las inmunizaciones: {}".format(df_inmu.duplicated().sum()))
#Una prueba del funcionamiento de drop_duplicates
#display(df_inmu[(df_inmu['ID_SAPS']==45) & (df_inmu['vacunas_tipo']=="VARICELA") ])
#display(df_inmu[(df_inmu['ID_SAPS']==45) & (df_inmu['vacunas_tipo']=="VARICELA") ].drop_duplicates())
# Out:
# Total Duplicados para las patologias: 2975
# Total Duplicados para los saps: 0
# Total Duplicados para las inmunizaciones: 12181

# %%
#Eliminación de duplicados
df_inmu=df_inmu.drop_duplicates()
df_pato=df_pato.drop_duplicates()
df_pato.head()
# Out:
#   ID_SAPS                SAPS      fecha
# 0      45  Dr. Saul Calmanash 2020-01-01  \
# 1      45  Dr. Saul Calmanash 2020-01-01
# 2      45  Dr. Saul Calmanash 2020-01-01
# 3      45  Dr. Saul Calmanash 2020-01-01
# 4      45  Dr. Saul Calmanash 2020-01-01
#
#                              patologia_desc
# 0  CONTROL DEL NIÑO SANO - CONTROL DE SALUD  \
# 1  CONTROL DEL NIÑO SANO - CONTROL DE SALUD
# 2  CONTROL DEL NIÑO SANO - CONTROL DE SALUD
# 3  CONTROL DEL NIÑO SANO - CONTROL DE SALUD
# 4  CONTROL DEL NIÑO SANO - CONTROL DE SALUD
#
#                                     agrupacion_CIE10 patologia_cod
# 0  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z001  \
# 1  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z001
# 2  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z001
# 3  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z001
# 4  PERSONAS EN CONTACTO CON LOS SERVICIOS DE SALU...          Z001
#
#    id_rango_etario  consulta_cantidad rango_etario       sexo
# 0                1                 18      < 1 AÑO   Femenino
# 1                1                 20      < 1 AÑO  Masculino
# 2                2                 22   1 - 4 AÑOS   Femenino
# 3                2                 20   1 - 4 AÑOS  Masculino
# 4                3                 25  5 - 14 AÑOS   Femenino

# %%
#guardo el resultado final en un nuevo archivo csv para las consultas por patología

df_pato.to_csv("consultas_por_patologia_limpio.csv",index=False)
df_saps.to_csv("listado_saps_limpio.csv",index=False)
df_inmu.to_csv("inmunizaciones_limpio.csv",index=False)
